# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
from scipy import stats
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
mev = pd.read_csv('mental health related emergency visit.csv')
mev.head(20)
# Out:
#                                                                                                                 Mental Health related Emergency Department visits by Age (years) for Total mental health presentations and Persons
# Age (years)        Presentation type                 Sex     Period Crude rate per 100,000 population LL 95% CI                                          UL 95% CI
# 11 years and under Total mental health presentations Persons 14/15  93.9                              88.4                                                    99.7
#                                                              15/16  112.1                             106.1                                                  118.3
#                                                              16/17  112.0                             106.1                                                  118.2
# ...

# %%
mental_health = []

# %%
mental_health['ED_visit'] = mev

# %%
psy_distress = pd.read_csv('psychological distress by Kessler 10 categories.csv')
psy_distress.head(10)
# Out:
#                                                                        Psychological distress by Kessler 10 categories by Psychological distress, Period and Age (years)
# Psychological distress           Period Age (years) Per cent LL 95% CI                                          UL 95% CI
# Moderate level of psych distress 2020   16-24 years 33.4     28.3                                                    38.4
#                                         25-34 years 29.0     24.4                                                    33.6
#                                         35-44 years 31.1     26.6                                                    35.6
#                                         45-54 years 25.9     22.2                                                    29.5
#                                         55-64 years 22.6     19.3                                                    25.9
# ...

# %%
suic = pd.read_csv('suicide.csv')
suic.head()
# Out:
#                                                            Suicide
# LHD        Period Rate per 100,000 population LL 95% CI  UL 95% CI
# Sydney LHD 2007   10.1                        7.6             13.1
#            2008   5.9                         4.1              8.4
#            2009   8.5                         6.2             11.3
#            2010   12.7                        9.9             15.9

# %%
surg_audit= pd.read_excel('Sample Surgical Audit Extract.xlsx')
surg_audit.head()
# Out:
#        MRN     SURNAME FORENAME GENDER DTTM_OF_BIRTH  AGE PRESENTING_PROBLEM  \
# 0  3246359     A Dabel    Naser      M    09/12/1993   27       appendicitis
# 1   482552  Abberfield    Craig      M    15/03/1969   52             NSTEMI
# 2   482552  Abberfield    Craig      M    15/03/1969   52             NSTEMI
# 3   482552  Abberfield    Craig      M    15/03/1969   52             NSTEMI
# 4   419426  Abberfield   Sheree      F    29/03/1979   42                NaN
#
#   SPECIALTY_CODE SPECIALTY_DESCRIPTION BOOKING_CONSULTANT_NAME  ...  \
# 0            ASU         Acute Surgery              Chen, Stan  ...
# 1            CAR            Cardiology           Davies, Allan  ...
# 2            CAR            Cardiology           Davies, Allan  ...
# 3            CAR            Cardiology           Davies, Allan  ...
# 4             GE      Gastroenterology          Foster, Robert  ...
#
#    CANCR_REASON CANCEL_COMMENT  CANCELLATION_REASON INTHEATRE_COMMENTS  \
# ...

# %%
surg_audit.dtypes
# Out:
# MRN                                  int64
# SURNAME                             object
# FORENAME                            object
# GENDER                              object
# DTTM_OF_BIRTH                       object
# AGE                                  int64
# PRESENTING_PROBLEM                  object
# SPECIALTY_CODE                      object
# SPECIALTY_DESCRIPTION               object
# BOOKING_CONSULTANT_NAME             object
# SECONDARY_SPECIALTY_DESCRIPTION    float64
# SURGICAL_CONSULTANT_NAME            object
# SECONDARY_CONSULTANT               float64
# SURGEON_OPERATING_NAME              object
# SURGICAL_ASSISTANT_1_NAME           object
# ADMIT_DTTM                          object
# DISCH_DTTM                          object
# AMO_NAME                            object
# AGSU_DISCHARGE_DTTM2                object
# AGSU_DISCHARGE_SPECIALTY2           object
# AGSU_DISCHARGE_PROCA2               object
# AGSU_LOS2                          float64
# ...

# %%
surg_audit.corr()
# Out:
#                                       MRN       AGE  \
# MRN                              1.000000 -0.559420
# AGE                             -0.559420  1.000000
# SECONDARY_SPECIALTY_DESCRIPTION       NaN       NaN
# SECONDARY_CONSULTANT                  NaN       NaN
# AGSU_LOS2                             NaN       NaN
# LOS_HOURS                       -0.191717  0.649578
# PROCEDURE_CODE                   0.274160 -0.402955
# PROCEDURE_SORT                   0.302748 -0.334588
# CANCEL_DTTM                           NaN       NaN
# CANCR_REASON                          NaN       NaN
# CANCEL_COMMENT                        NaN       NaN
# CANCELLATION_REASON                   NaN       NaN
# DAYS_ON_LIST                    -1.000000  1.000000
#
#                                  SECONDARY_SPECIALTY_DESCRIPTION  \
# MRN                                                          NaN
# AGE                                                          NaN
# ...

# %%
surg_audit['WAITING_LIST_CATEGORY'].value_counts()
# Out:
# 2-Within 90 days    7
# Name: WAITING_LIST_CATEGORY, dtype: int64

# %%
surg_audit = surg_audit.reset_index()

# %%
surg_audit.columns = surg_audit.columns.str.lower()

# %%
surg_audit
# Out:
#     index      mrn     surname     forename gender dttm_of_birth  age  \
# 0       0  3246359     A Dabel        Naser      M    09/12/1993   27
# 1       1   482552  Abberfield        Craig      M    15/03/1969   52
# 2       2   482552  Abberfield        Craig      M    15/03/1969   52
# 3       3   482552  Abberfield        Craig      M    15/03/1969   52
# 4       4   419426  Abberfield       Sheree      F    29/03/1979   42
# 5       5  3234051    Abberton       Alysha      F    23/10/1997   23
# 6       6  3234051    Abberton       Alysha      F    23/10/1997   23
# 7       7  3234051    Abberton       Alysha      F    23/10/1997   23
# 8       8  3234051    Abberton       Alysha      F    23/10/1997   23
# 9       9  3234051    Abberton       Alysha      F    23/10/1997   23
# 10     10  3234051    Abberton       Alysha      F    23/10/1997   23
# 11     11  3234051    Abberton       Alysha      F    23/10/1997   23
# ...

# %%
surg_audit.isnull().sum()
# Out:
# index                               0
# mrn                                 0
# surname                             0
# forename                            0
# gender                              0
# dttm_of_birth                       0
# age                                 0
# presenting_problem                  1
# specialty_code                      0
# specialty_description               0
# booking_consultant_name             0
# secondary_specialty_description    19
# surgical_consultant_name            4
# secondary_consultant               19
# surgeon_operating_name              4
# surgical_assistant_1_name          14
# admit_dttm                          0
# disch_dttm                          0
# amo_name                            1
# agsu_discharge_dttm2               18
# agsu_discharge_specialty2          18
# agsu_discharge_proca2              18
# agsu_los2                          18
# los_hours                           0
# stay_type                           0
# ...

# %%
mh_age = pd.read_excel('age.xlsx')
mh_age.head()
# Out:
#           Prescription type           Prescription  \
# 0  Subsidised prescriptions  Antipsychotics (N05A)
# 1  Subsidised prescriptions  Antipsychotics (N05A)
# 2  Subsidised prescriptions  Antipsychotics (N05A)
# 3  Subsidised prescriptions  Antipsychotics (N05A)
# 4  Subsidised prescriptions  Antipsychotics (N05A)
#
#                          Count    Age group    2013–14    2014–15    2015–16  \
# 0  Rate (per 1,000 population)    0–4 years    0.93510    0.92558    0.99694
# 1  Rate (per 1,000 population)   5–11 years   16.30270   16.90685   17.83076
# 2  Rate (per 1,000 population)  12–17 years   36.39089   36.06574   36.19579
# 3  Rate (per 1,000 population)  18–24 years   76.51879   75.16565   75.26122
# 4  Rate (per 1,000 population)  25–34 years  136.82208  134.35470  130.34581
#
#      2016–17    2017–18    2018–19    2019–20  \
# 0    0.97857    1.05861    1.09902    1.18689
# 1   18.18038   19.65762   20.20833   19.97689
# 2   35.84552   37.31220   37.72919   38.77485
# ...

# %%
mh_med_prac = pd.read_excel('med_prac.xlsx')
mh_med_prac.head()
# Out:
#           Prescription type           Prescription  \
# 0  Subsidised prescriptions  Antipsychotics (N05A)
# 1  Subsidised prescriptions  Antipsychotics (N05A)
# 2  Subsidised prescriptions  Antipsychotics (N05A)
# 3  Subsidised prescriptions  Antipsychotics (N05A)
# 4  Subsidised prescriptions                    NaN
#
#            Medical Practitioner    2005–06    2006–07    2007–08    2008–09  \
# 0         General practitioners  1425386.0  1546887.0  1752272.0  1952263.0
# 1  Non-psychiatrist specialists    45472.0    47429.0    60039.0    65088.0
# 2                 Psychiatrists   389006.0   415192.0   459274.0   503753.0
# 3                   Subtotal(g)  1864192.0  2012600.0  2274100.0  2523337.0
# 4                           NaN        NaN        NaN        NaN        NaN
#
#      2009–10    2010–11    2011–12    2012–13  2013–14(b)    2014–15  \
# 0  2092423.0  2231199.0  2399440.0  2545314.0   2733187.0  2794216.0
# ...

# %%
mh = mh_age.join(mh_med_prac, how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 mh = mh_age.join(mh_med_prac, how='left')
#
# File ~/opt/anaconda3/envs/IOD/lib/python3.8/site-packages/pandas/core/frame.py:8110, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    7990 def join(
#    7991     self, other, on=None, how="left", lsuffix="", rsuffix="", sort=False
#    7992 ) -> DataFrame:
#    7993     """
#    7994     Join columns of another DataFrame.
#    7995
#    (...)
#    8108     5  K5  A5  NaN
#    8109     """
# -> 8110     return self._join_compat(
#    8111         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112     )
#
# File ~/opt/anaconda3/envs/IOD/lib/python3.8/site-packages/pandas/core/frame.py:8135, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8126     if how == "cross":
# ...
