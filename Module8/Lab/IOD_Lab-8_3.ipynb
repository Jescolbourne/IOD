# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 8.3: Working with Text
# - Using [NLTK](http://www.nltk.org) (Natural Language Toolkit)
# - Using [spaCy](https://spacy.io)
#
# INSTRUCTIONS:
# - Run the cells
# - Observe and understand the results
# - Answer the questions

# %% [markdown]
# ## Import libraries

# %%
## Import Libraries
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import Counter

import regex as re
import spacy
#import nltk

# %% [markdown]
# ## Load data

# %%
## Loading the data

input_file = 'ncc-1701-D.txt'

with open(input_file, 'r') as f:
    text = f.read()

# %%
text
# Out:
# 'USS Enterprise (NCC-1701-D)\n\n"For five hundred years, every ship that has borne the name of the Enterprise has become a legend. This one is no different."\n\nThe USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise. During her career, the Enterprise served as the Federation flagship. The Enterprise was destroyed during the Battle of Veridian III in 2371.\n\n==History==\n===Construction and launch===\nThe Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system. The construction was a massive undertaking, involving thousands of people across disciplines. Construction was supervised by Commander Orfil Quinteros. Dr. Leah Brahms was responsible for much of the Enterprise\'s warp propulsion system design. Some of the Enterprise\'s components were derived from technology originally developed on the USS Pegasus.\n\nOne of the ship\'s nacelle tube was the site of a multiple murder-suicide while she was still under construction at Utopia Planitia. A member of the construction team, Walter Pierce, became jealous of a former lover\'s new relationship. He killed the two officers, Marla Finn and William Hodges, then disposed of their bodies in the plasma stream. Pierce committed suicide in the same manner, leaving a telepathic imprint in a bulkhead that was not discovered until 2370.\n\nOn stardate 40759.5, in the year 2363, the Enterprise was launched from Mars. On stardate 41025.5, the Enterprise was commissioned.\n\nThese stardates weren\'t mentioned in dialog; they were from the Enterprise dedication plaque.\n\nFinal systems completion and shakedown was conducted at Earth Station McKinley. Captain Jean-Luc Picard took command of the ship on stardate 41148 at the order of Rear Admiral Norah Satie.\n\n===Legacy===\nCommander Riker was upset over the loss of the Enterprise. Having hoped he would one day command the ship, he was disappointed that he never got that opportunity. However, Picard expressed doubt that the Enterprise-D would be the last vessel to carry the name.\n\nThe Enterprise was so dear to Worf that, shortly after being reassigned to Deep Space 9 in 2372, he briefly considered resigning from Starfleet. Station commander Captain Benjamin Sisko expressed regret on the loss of the Enterprise and offered his condolences over the destruction of the ship to Worf, saying the Enterprise "was a good ship."\n\nCaptain Picard\'s belief that the Enterprise-D would not be the final ship to bear the name was borne out with the christening of the Class Sovereign USS Enterprise NCC-1701-E, later the same year. In that instance, the legacy of the Enterprise continued with Picard reprising his role as CO and selecting most of the former crew from the Enterprise-D, with the notable exception of Worf due to his most recent assignment to DS9 (though he temporarily joined the Enterprise-E crew on several of their more notable missions).'

# %% [markdown]
# ## Inspect the data

# %%
print(text[:1000])
# Out:
# USS Enterprise (NCC-1701-D)
#
# "For five hundred years, every ship that has borne the name of the Enterprise has become a legend. This one is no different."
#
# The USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise. During her career, the Enterprise served as the Federation flagship. The Enterprise was destroyed during the Battle of Veridian III in 2371.
#
# ==History==
# ===Construction and launch===
# The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system. The construction was a massive undertaking, involving thousands of people across disciplines. Construction was supervised by Commander Orfil Quinteros. Dr. Leah Brahms was responsible for much of the Enterprise's warp propulsion system design. Some of the Enterprise's components were derived from technology originally developed on the USS Pegasus.
#
# One of the ship's nacelle tube was

# %% [markdown]
# ## Work the data
# - if necessary or desired
#     - remove text or content, e.g. quotes (") or metadata (===)
#     - add content or markers, e.g. (#FLAG, --NAME--)
#     - remove or convert special symbols, e.g. "é" to "e"
#     - remove or convert emoticons

# %%
# ANSWER
text = re.sub(r'[="]', '', text)
print(text[:1000])
# Out:
# USS Enterprise (NCC-1701-D)
#
# For five hundred years, every ship that has borne the name of the Enterprise has become a legend This one is no different
#
# The USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise During her career, the Enterprise served as the Federation flagship The Enterprise was destroyed during the Battle of Veridian III in 2371
#
# History
# Construction and launch
# The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system The construction was a massive undertaking, involving thousands of people across disciplines Construction was supervised by Commander Orfil Quinteros Dr Leah Brahms was responsible for much of the Enterprise's warp propulsion system design Some of the Enterprise's components were derived from technology originally developed on the USS Pegasus
#
# One of the ship's nacelle tube was the site of a multiple

# %% [markdown]
# ## Helper method

# %%
# create a bar chart of the frequency of the words in the text
def plot_words(tokens, top = 30):
    tokens_counter = Counter(tokens)
    tok = [t for (t, _) in tokens_counter.most_common()]
    val = [v for (_, v) in tokens_counter.most_common()]

    plt.figure(figsize = (16, 6))
    plt.bar(tok[:top], val[:top])
    plt.title('Number of terms: %d' % len(tokens_counter))
    plt.xticks(rotation = 90)

    plt.show()

# %%
plot_words(text)

# %% [markdown]
# ## spaCy model invocation and text processing
# spaCy does the processing of the text as part of the reading of the data.

# %%
# load spaCy and the English model
nlp = spacy.load("en_core_web_sm")
# process the text
doc = nlp(text)

# %% [markdown]
# ## Tokenise

# %%
# only show the results
# spaCy has done it already
for i, t in enumerate(doc):
    print('%2d| %r' % (i+1, t.text))
    if t.text == '.':
        break
# Out:
#  1| 'USS'
#  2| 'Enterprise'
#  3| '('
#  4| 'NCC-1701'
#  5| '-'
#  6| 'D'
#  7| ')'
#  8| '\n\n'
#  9| 'For'
# 10| 'five'
# 11| 'hundred'
# 12| 'years'
# 13| ','
# 14| 'every'
# 15| 'ship'
# 16| 'that'
# 17| 'has'
# 18| 'borne'
# 19| 'the'
# 20| 'name'
# 21| 'of'
# 22| 'the'
# 23| 'Enterprise'
# 24| 'has'
# 25| 'become'
# 26| 'a'
# 27| 'legend'
# 28| 'This'
# 29| 'one'
# 30| 'is'
# 31| 'no'
# 32| 'different'
# 33| '\n\n'
# 34| 'The'
# 35| 'USS'
# 36| 'Enterprise'
# 37| '('
# 38| 'NCC-1701'
# 39| '-'
# 40| 'D'
# 41| ')'
# 42| 'was'
# 43| 'a'
# 44| '24th'
# 45| 'century'
# 46| 'United'
# 47| 'Federation'
# 48| 'of'
# 49| 'Planets'
# 50| 'Galaxy'
# 51| 'Class'
# 52| 'starship'
# 53| 'operated'
# 54| 'by'
# 55| 'Starfleet'
# 56| ','
# 57| 'and'
# 58| 'the'
# 59| 'fifth'
# 60| 'Federation'
# 61| 'ship'
# 62| 'to'
# 63| 'bear'
# 64| 'the'
# 65| 'name'
# 66| 'Enterprise'
# 67| 'During'
# 68| 'her'
# 69| 'career'
# 70| ','
# 71| 'the'
# 72| 'Enterprise'
# 73| 'served'
# 74| 'as'
# 75| 'the'
# 76| 'Federation'
# 77| 'flagship'
# 78| 'The'
# 79| 'Enterprise'
# 80| 'was'
# 81| 'destroyed'
# 82| 'during'
# 83| 'the'
# 84| 'Battle'
# 85| 'of'
# 86| 'Veridian'
# 87| 'III'
# 88| 'in'
# 89| '2371'
# 90| '\n\n'
# 91| 'History'
# 92| '\n'
# 93| 'Construction'
# 94| 'and'
# 95| 'launch'
# 96| '\n'
# 97| 'The'
# 98| 'Enterprise'
# 99| 'was'
# 100| 'built'
# 101| 'at'
# 102| 'Utopia'
# 103| 'Planitia'
# 104| 'Fleet'
# 105| 'Yards'
# 106| 'orbiting'
# 107| 'Mars'
# 108| 'in'
# 109| 'the'
# 110| 'Solar'
# 111| 'system'
# 112| 'The'
# 113| 'construction'
# 114| 'was'
# 115| 'a'
# 116| 'massive'
# 117| 'undertaking'
# 118| ','
# 119| 'involving'
# 120| 'thousands'
# 121| 'of'
# 122| 'people'
# 123| 'across'
# 124| 'disciplines'
# 125| 'Construction'
# 126| 'was'
# 127| 'supervised'
# 128| 'by'
# 129| 'Commander'
# 130| 'Orfil'
# 131| 'Quinteros'
# 132| 'Dr'
# 133| 'Leah'
# 134| 'Brahms'
# 135| 'was'
# 136| 'responsible'
# 137| 'for'
# 138| 'much'
# 139| 'of'
# 140| 'the'
# 141| 'Enterprise'
# 142| "'s"
# 143| 'warp'
# 144| 'propulsion'
# 145| 'system'
# 146| 'design'
# 147| 'Some'
# 148| 'of'
# 149| 'the'
# 150| 'Enterprise'
# 151| "'s"
# 152| 'components'
# 153| 'were'
# 154| 'derived'
# 155| 'from'
# 156| 'technology'
# 157| 'originally'
# 158| 'developed'
# 159| 'on'
# 160| 'the'
# 161| 'USS'
# 162| 'Pegasus'
# 163| '\n\n'
# 164| 'One'
# 165| 'of'
# 166| 'the'
# 167| 'ship'
# 168| "'s"
# 169| 'nacelle'
# 170| 'tube'
# 171| 'was'
# 172| 'the'
# 173| 'site'
# 174| 'of'
# 175| 'a'
# 176| 'multiple'
# 177| 'murder'
# 178| '-'
# 179| 'suicide'
# 180| 'while'
# 181| 'she'
# 182| 'was'
# 183| 'still'
# 184| 'under'
# 185| 'construction'
# 186| 'at'
# 187| 'Utopia'
# 188| 'Planitia'
# 189| 'A'
# 190| 'member'
# 191| 'of'
# 192| 'the'
# 193| 'construction'
# 194| 'team'
# 195| ','
# 196| 'Walter'
# 197| 'Pierce'
# 198| ','
# 199| 'became'
# 200| 'jealous'
# 201| 'of'
# 202| 'a'
# 203| 'former'
# 204| 'lover'
# 205| "'s"
# 206| 'new'
# 207| 'relationship'
# 208| 'He'
# 209| 'killed'
# 210| 'the'
# 211| 'two'
# 212| 'officers'
# 213| ','
# 214| 'Marla'
# 215| 'Finn'
# 216| 'and'
# 217| 'William'
# 218| 'Hodges'
# 219| ','
# 220| 'then'
# 221| 'disposed'
# 222| 'of'
# 223| 'their'
# 224| 'bodies'
# 225| 'in'
# 226| 'the'
# 227| 'plasma'
# 228| 'stream'
# 229| 'Pierce'
# 230| 'committed'
# 231| 'suicide'
# 232| 'in'
# 233| 'the'
# 234| 'same'
# 235| 'manner'
# 236| ','
# 237| 'leaving'
# 238| 'a'
# 239| 'telepathic'
# 240| 'imprint'
# 241| 'in'
# 242| 'a'
# 243| 'bulkhead'
# 244| 'that'
# 245| 'was'
# 246| 'not'
# 247| 'discovered'
# 248| 'until'
# 249| '2370'
# 250| '\n\n'
# 251| 'On'
# 252| 'stardate'
# 253| '407595'
# 254| ','
# 255| 'in'
# 256| 'the'
# 257| 'year'
# 258| '2363'
# 259| ','
# 260| 'the'
# 261| 'Enterprise'
# 262| 'was'
# 263| 'launched'
# 264| 'from'
# 265| 'Mars'
# 266| 'On'
# 267| 'stardate'
# 268| '410255'
# 269| ','
# 270| 'the'
# 271| 'Enterprise'
# 272| 'was'
# 273| 'commissioned'
# 274| '\n\n'
# 275| 'These'
# 276| 'stardates'
# 277| 'were'
# 278| "n't"
# 279| 'mentioned'
# 280| 'in'
# 281| 'dialog'
# 282| ';'
# 283| 'they'
# 284| 'were'
# 285| 'from'
# 286| 'the'
# 287| 'Enterprise'
# 288| 'dedication'
# 289| 'plaque'
# 290| '\n\n'
# 291| 'Final'
# 292| 'systems'
# 293| 'completion'
# 294| 'and'
# 295| 'shakedown'
# 296| 'was'
# 297| 'conducted'
# 298| 'at'
# 299| 'Earth'
# 300| 'Station'
# 301| 'McKinley'
# 302| 'Captain'
# 303| 'Jean'
# 304| '-'
# 305| 'Luc'
# 306| 'Picard'
# 307| 'took'
# 308| 'command'
# 309| 'of'
# 310| 'the'
# 311| 'ship'
# 312| 'on'
# 313| 'stardate'
# 314| '41148'
# 315| 'at'
# 316| 'the'
# 317| 'order'
# 318| 'of'
# 319| 'Rear'
# 320| 'Admiral'
# 321| 'Norah'
# 322| 'Satie'
# 323| '\n\n'
# 324| 'Legacy'
# 325| '\n'
# 326| 'Commander'
# 327| 'Riker'
# 328| 'was'
# 329| 'upset'
# 330| 'over'
# 331| 'the'
# 332| 'loss'
# 333| 'of'
# 334| 'the'
# 335| 'Enterprise'
# 336| 'Having'
# 337| 'hoped'
# 338| 'he'
# 339| 'would'
# 340| 'one'
# 341| 'day'
# 342| 'command'
# 343| 'the'
# 344| 'ship'
# 345| ','
# 346| 'he'
# 347| 'was'
# 348| 'disappointed'
# 349| 'that'
# 350| 'he'
# 351| 'never'
# 352| 'got'
# 353| 'that'
# 354| 'opportunity'
# 355| 'However'
# 356| ','
# 357| 'Picard'
# 358| 'expressed'
# 359| 'doubt'
# 360| 'that'
# 361| 'the'
# 362| 'Enterprise'
# 363| '-'
# 364| 'D'
# 365| 'would'
# 366| 'be'
# 367| 'the'
# 368| 'last'
# 369| 'vessel'
# 370| 'to'
# 371| 'carry'
# 372| 'the'
# 373| 'name'
# 374| '\n\n'
# 375| 'The'
# 376| 'Enterprise'
# 377| 'was'
# 378| 'so'
# 379| 'dear'
# 380| 'to'
# 381| 'Worf'
# 382| 'that'
# 383| ','
# 384| 'shortly'
# 385| 'after'
# 386| 'being'
# 387| 'reassigned'
# 388| 'to'
# 389| 'Deep'
# 390| 'Space'
# 391| '9'
# 392| 'in'
# 393| '2372'
# 394| ','
# 395| 'he'
# 396| 'briefly'
# 397| 'considered'
# 398| 'resigning'
# 399| 'from'
# 400| 'Starfleet'
# 401| 'Station'
# 402| 'commander'
# 403| 'Captain'
# 404| 'Benjamin'
# 405| 'Sisko'
# 406| 'expressed'
# 407| 'regret'
# 408| 'on'
# 409| 'the'
# 410| 'loss'
# 411| 'of'
# 412| 'the'
# 413| 'Enterprise'
# 414| 'and'
# 415| 'offered'
# 416| 'his'
# 417| 'condolences'
# 418| 'over'
# 419| 'the'
# 420| 'destruction'
# 421| 'of'
# 422| 'the'
# 423| 'ship'
# 424| 'to'
# 425| 'Worf'
# 426| ','
# 427| 'saying'
# 428| 'the'
# 429| 'Enterprise'
# 430| 'was'
# 431| 'a'
# 432| 'good'
# 433| 'ship'
# 434| '\n\n'
# 435| 'Captain'
# 436| 'Picard'
# 437| "'s"
# 438| 'belief'
# 439| 'that'
# 440| 'the'
# 441| 'Enterprise'
# 442| '-'
# 443| 'D'
# 444| 'would'
# 445| 'not'
# 446| 'be'
# 447| 'the'
# 448| 'final'
# 449| 'ship'
# 450| 'to'
# 451| 'bear'
# 452| 'the'
# 453| 'name'
# 454| 'was'
# 455| 'borne'
# 456| 'out'
# 457| 'with'
# 458| 'the'
# 459| 'christening'
# 460| 'of'
# 461| 'the'
# 462| 'Class'
# 463| 'Sovereign'
# 464| 'USS'
# 465| 'Enterprise'
# 466| 'NCC-1701'
# 467| '-'
# 468| 'E'
# 469| ','
# 470| 'later'
# 471| 'the'
# 472| 'same'
# 473| 'year'
# 474| 'In'
# 475| 'that'
# 476| 'instance'
# 477| ','
# 478| 'the'
# 479| 'legacy'
# 480| 'of'
# 481| 'the'
# 482| 'Enterprise'
# 483| 'continued'
# 484| 'with'
# 485| 'Picard'
# 486| 'reprising'
# 487| 'his'
# 488| 'role'
# 489| 'as'
# 490| 'CO'
# 491| 'and'
# 492| 'selecting'
# 493| 'most'
# 494| 'of'
# 495| 'the'
# 496| 'former'
# 497| 'crew'
# 498| 'from'
# 499| 'the'
# 500| 'Enterprise'
# 501| '-'
# 502| 'D'
# 503| ','
# 504| 'with'
# 505| 'the'
# 506| 'notable'
# 507| 'exception'
# 508| 'of'
# 509| 'Worf'
# 510| 'due'
# 511| 'to'
# 512| 'his'
# 513| 'most'
# 514| 'recent'
# 515| 'assignment'
# 516| 'to'
# 517| 'DS9'
# 518| '('
# 519| 'though'
# 520| 'he'
# 521| 'temporarily'
# 522| 'joined'
# 523| 'the'
# 524| 'Enterprise'
# 525| '-'
# 526| 'E'
# 527| 'crew'
# 528| 'on'
# 529| 'several'
# 530| 'of'
# 531| 'their'
# 532| 'more'
# 533| 'notable'
# 534| 'missions'
# 535| ')'

# %%
plot_words(['%r' % t.text for t in doc])

# %% [markdown]
# ### Stop Words

# %%
## spaCy
print('i | with stop words without')
print('--| --------------- ------------')

# for all the tokens
for i, t in enumerate(doc):
    print('%2d| %-15r %r' % (i+1, t.text, ('' if t.is_stop else t.text)))

    # break after the first sentence
    if t.text == '.':
        break
# Out:
# i | with stop words without
# --| --------------- ------------
#  1| 'USS'           'USS'
#  2| 'Enterprise'    'Enterprise'
#  3| '('             '('
#  4| 'NCC-1701'      'NCC-1701'
#  5| '-'             '-'
#  6| 'D'             'D'
#  7| ')'             ')'
#  8| '\n\n'          '\n\n'
#  9| 'For'           ''
# 10| 'five'          ''
# 11| 'hundred'       ''
# 12| 'years'         'years'
# 13| ','             ','
# 14| 'every'         ''
# 15| 'ship'          'ship'
# 16| 'that'          ''
# 17| 'has'           ''
# 18| 'borne'         'borne'
# 19| 'the'           ''
# 20| 'name'          ''
# 21| 'of'            ''
# 22| 'the'           ''
# 23| 'Enterprise'    'Enterprise'
# 24| 'has'           ''
# 25| 'become'        ''
# 26| 'a'             ''
# 27| 'legend'        'legend'
# 28| 'This'          ''
# 29| 'one'           ''
# 30| 'is'            ''
# 31| 'no'            ''
# 32| 'different'     'different'
# 33| '\n\n'          '\n\n'
# 34| 'The'           ''
# 35| 'USS'           'USS'
# 36| 'Enterprise'    'Enterprise'
# 37| '('             '('
# 38| 'NCC-1701'      'NCC-1701'
# 39| '-'             '-'
# 40| 'D'             'D'
# 41| ')'             ')'
# 42| 'was'           ''
# 43| 'a'             ''
# 44| '24th'          '24th'
# 45| 'century'       'century'
# 46| 'United'        'United'
# 47| 'Federation'    'Federation'
# 48| 'of'            ''
# 49| 'Planets'       'Planets'
# 50| 'Galaxy'        'Galaxy'
# 51| 'Class'         'Class'
# 52| 'starship'      'starship'
# 53| 'operated'      'operated'
# 54| 'by'            ''
# 55| 'Starfleet'     'Starfleet'
# 56| ','             ','
# 57| 'and'           ''
# 58| 'the'           ''
# 59| 'fifth'         'fifth'
# 60| 'Federation'    'Federation'
# 61| 'ship'          'ship'
# 62| 'to'            ''
# 63| 'bear'          'bear'
# 64| 'the'           ''
# 65| 'name'          ''
# 66| 'Enterprise'    'Enterprise'
# 67| 'During'        ''
# 68| 'her'           ''
# 69| 'career'        'career'
# 70| ','             ','
# 71| 'the'           ''
# 72| 'Enterprise'    'Enterprise'
# 73| 'served'        'served'
# 74| 'as'            ''
# 75| 'the'           ''
# 76| 'Federation'    'Federation'
# 77| 'flagship'      'flagship'
# 78| 'The'           ''
# 79| 'Enterprise'    'Enterprise'
# 80| 'was'           ''
# 81| 'destroyed'     'destroyed'
# 82| 'during'        ''
# 83| 'the'           ''
# 84| 'Battle'        'Battle'
# 85| 'of'            ''
# 86| 'Veridian'      'Veridian'
# 87| 'III'           'III'
# 88| 'in'            ''
# 89| '2371'          '2371'
# 90| '\n\n'          '\n\n'
# 91| 'History'       'History'
# 92| '\n'            '\n'
# 93| 'Construction'  'Construction'
# 94| 'and'           ''
# 95| 'launch'        'launch'
# 96| '\n'            '\n'
# 97| 'The'           ''
# 98| 'Enterprise'    'Enterprise'
# 99| 'was'           ''
# 100| 'built'         'built'
# 101| 'at'            ''
# 102| 'Utopia'        'Utopia'
# 103| 'Planitia'      'Planitia'
# 104| 'Fleet'         'Fleet'
# 105| 'Yards'         'Yards'
# 106| 'orbiting'      'orbiting'
# 107| 'Mars'          'Mars'
# 108| 'in'            ''
# 109| 'the'           ''
# 110| 'Solar'         'Solar'
# 111| 'system'        'system'
# 112| 'The'           ''
# 113| 'construction'  'construction'
# 114| 'was'           ''
# 115| 'a'             ''
# 116| 'massive'       'massive'
# 117| 'undertaking'   'undertaking'
# 118| ','             ','
# 119| 'involving'     'involving'
# 120| 'thousands'     'thousands'
# 121| 'of'            ''
# 122| 'people'        'people'
# 123| 'across'        ''
# 124| 'disciplines'   'disciplines'
# 125| 'Construction'  'Construction'
# 126| 'was'           ''
# 127| 'supervised'    'supervised'
# 128| 'by'            ''
# 129| 'Commander'     'Commander'
# 130| 'Orfil'         'Orfil'
# 131| 'Quinteros'     'Quinteros'
# 132| 'Dr'            'Dr'
# 133| 'Leah'          'Leah'
# 134| 'Brahms'        'Brahms'
# 135| 'was'           ''
# 136| 'responsible'   'responsible'
# 137| 'for'           ''
# 138| 'much'          ''
# 139| 'of'            ''
# 140| 'the'           ''
# 141| 'Enterprise'    'Enterprise'
# 142| "'s"            ''
# 143| 'warp'          'warp'
# 144| 'propulsion'    'propulsion'
# 145| 'system'        'system'
# 146| 'design'        'design'
# 147| 'Some'          ''
# 148| 'of'            ''
# 149| 'the'           ''
# 150| 'Enterprise'    'Enterprise'
# 151| "'s"            ''
# 152| 'components'    'components'
# 153| 'were'          ''
# 154| 'derived'       'derived'
# 155| 'from'          ''
# 156| 'technology'    'technology'
# 157| 'originally'    'originally'
# 158| 'developed'     'developed'
# 159| 'on'            ''
# 160| 'the'           ''
# 161| 'USS'           'USS'
# 162| 'Pegasus'       'Pegasus'
# 163| '\n\n'          '\n\n'
# 164| 'One'           ''
# 165| 'of'            ''
# 166| 'the'           ''
# 167| 'ship'          'ship'
# 168| "'s"            ''
# 169| 'nacelle'       'nacelle'
# 170| 'tube'          'tube'
# 171| 'was'           ''
# 172| 'the'           ''
# 173| 'site'          'site'
# 174| 'of'            ''
# 175| 'a'             ''
# 176| 'multiple'      'multiple'
# 177| 'murder'        'murder'
# 178| '-'             '-'
# 179| 'suicide'       'suicide'
# 180| 'while'         ''
# 181| 'she'           ''
# 182| 'was'           ''
# 183| 'still'         ''
# 184| 'under'         ''
# 185| 'construction'  'construction'
# 186| 'at'            ''
# 187| 'Utopia'        'Utopia'
# 188| 'Planitia'      'Planitia'
# 189| 'A'             ''
# 190| 'member'        'member'
# 191| 'of'            ''
# 192| 'the'           ''
# 193| 'construction'  'construction'
# 194| 'team'          'team'
# 195| ','             ','
# 196| 'Walter'        'Walter'
# 197| 'Pierce'        'Pierce'
# 198| ','             ','
# 199| 'became'        ''
# 200| 'jealous'       'jealous'
# 201| 'of'            ''
# 202| 'a'             ''
# 203| 'former'        ''
# 204| 'lover'         'lover'
# 205| "'s"            ''
# 206| 'new'           'new'
# 207| 'relationship'  'relationship'
# 208| 'He'            ''
# 209| 'killed'        'killed'
# 210| 'the'           ''
# 211| 'two'           ''
# 212| 'officers'      'officers'
# 213| ','             ','
# 214| 'Marla'         'Marla'
# 215| 'Finn'          'Finn'
# 216| 'and'           ''
# 217| 'William'       'William'
# 218| 'Hodges'        'Hodges'
# 219| ','             ','
# 220| 'then'          ''
# 221| 'disposed'      'disposed'
# 222| 'of'            ''
# 223| 'their'         ''
# 224| 'bodies'        'bodies'
# 225| 'in'            ''
# 226| 'the'           ''
# 227| 'plasma'        'plasma'
# 228| 'stream'        'stream'
# 229| 'Pierce'        'Pierce'
# 230| 'committed'     'committed'
# 231| 'suicide'       'suicide'
# 232| 'in'            ''
# 233| 'the'           ''
# 234| 'same'          ''
# 235| 'manner'        'manner'
# 236| ','             ','
# 237| 'leaving'       'leaving'
# 238| 'a'             ''
# 239| 'telepathic'    'telepathic'
# 240| 'imprint'       'imprint'
# 241| 'in'            ''
# 242| 'a'             ''
# 243| 'bulkhead'      'bulkhead'
# 244| 'that'          ''
# 245| 'was'           ''
# 246| 'not'           ''
# 247| 'discovered'    'discovered'
# 248| 'until'         ''
# 249| '2370'          '2370'
# 250| '\n\n'          '\n\n'
# 251| 'On'            ''
# 252| 'stardate'      'stardate'
# 253| '407595'        '407595'
# 254| ','             ','
# 255| 'in'            ''
# 256| 'the'           ''
# 257| 'year'          'year'
# 258| '2363'          '2363'
# 259| ','             ','
# 260| 'the'           ''
# 261| 'Enterprise'    'Enterprise'
# 262| 'was'           ''
# 263| 'launched'      'launched'
# 264| 'from'          ''
# 265| 'Mars'          'Mars'
# 266| 'On'            ''
# 267| 'stardate'      'stardate'
# 268| '410255'        '410255'
# 269| ','             ','
# 270| 'the'           ''
# 271| 'Enterprise'    'Enterprise'
# 272| 'was'           ''
# 273| 'commissioned'  'commissioned'
# 274| '\n\n'          '\n\n'
# 275| 'These'         ''
# 276| 'stardates'     'stardates'
# 277| 'were'          ''
# 278| "n't"           ''
# 279| 'mentioned'     'mentioned'
# 280| 'in'            ''
# 281| 'dialog'        'dialog'
# 282| ';'             ';'
# 283| 'they'          ''
# 284| 'were'          ''
# 285| 'from'          ''
# 286| 'the'           ''
# 287| 'Enterprise'    'Enterprise'
# 288| 'dedication'    'dedication'
# 289| 'plaque'        'plaque'
# 290| '\n\n'          '\n\n'
# 291| 'Final'         'Final'
# 292| 'systems'       'systems'
# 293| 'completion'    'completion'
# 294| 'and'           ''
# 295| 'shakedown'     'shakedown'
# 296| 'was'           ''
# 297| 'conducted'     'conducted'
# 298| 'at'            ''
# 299| 'Earth'         'Earth'
# 300| 'Station'       'Station'
# 301| 'McKinley'      'McKinley'
# 302| 'Captain'       'Captain'
# 303| 'Jean'          'Jean'
# 304| '-'             '-'
# 305| 'Luc'           'Luc'
# 306| 'Picard'        'Picard'
# 307| 'took'          'took'
# 308| 'command'       'command'
# 309| 'of'            ''
# 310| 'the'           ''
# 311| 'ship'          'ship'
# 312| 'on'            ''
# 313| 'stardate'      'stardate'
# 314| '41148'         '41148'
# 315| 'at'            ''
# 316| 'the'           ''
# 317| 'order'         'order'
# 318| 'of'            ''
# 319| 'Rear'          'Rear'
# 320| 'Admiral'       'Admiral'
# 321| 'Norah'         'Norah'
# 322| 'Satie'         'Satie'
# 323| '\n\n'          '\n\n'
# 324| 'Legacy'        'Legacy'
# 325| '\n'            '\n'
# 326| 'Commander'     'Commander'
# 327| 'Riker'         'Riker'
# 328| 'was'           ''
# 329| 'upset'         'upset'
# 330| 'over'          ''
# 331| 'the'           ''
# 332| 'loss'          'loss'
# 333| 'of'            ''
# 334| 'the'           ''
# 335| 'Enterprise'    'Enterprise'
# 336| 'Having'        'Having'
# 337| 'hoped'         'hoped'
# 338| 'he'            ''
# 339| 'would'         ''
# 340| 'one'           ''
# 341| 'day'           'day'
# 342| 'command'       'command'
# 343| 'the'           ''
# 344| 'ship'          'ship'
# 345| ','             ','
# 346| 'he'            ''
# 347| 'was'           ''
# 348| 'disappointed'  'disappointed'
# 349| 'that'          ''
# 350| 'he'            ''
# 351| 'never'         ''
# 352| 'got'           'got'
# 353| 'that'          ''
# 354| 'opportunity'   'opportunity'
# 355| 'However'       ''
# 356| ','             ','
# 357| 'Picard'        'Picard'
# 358| 'expressed'     'expressed'
# 359| 'doubt'         'doubt'
# 360| 'that'          ''
# 361| 'the'           ''
# 362| 'Enterprise'    'Enterprise'
# 363| '-'             '-'
# 364| 'D'             'D'
# 365| 'would'         ''
# 366| 'be'            ''
# 367| 'the'           ''
# 368| 'last'          ''
# 369| 'vessel'        'vessel'
# 370| 'to'            ''
# 371| 'carry'         'carry'
# 372| 'the'           ''
# 373| 'name'          ''
# 374| '\n\n'          '\n\n'
# 375| 'The'           ''
# 376| 'Enterprise'    'Enterprise'
# 377| 'was'           ''
# 378| 'so'            ''
# 379| 'dear'          'dear'
# 380| 'to'            ''
# 381| 'Worf'          'Worf'
# 382| 'that'          ''
# 383| ','             ','
# 384| 'shortly'       'shortly'
# 385| 'after'         ''
# 386| 'being'         ''
# 387| 'reassigned'    'reassigned'
# 388| 'to'            ''
# 389| 'Deep'          'Deep'
# 390| 'Space'         'Space'
# 391| '9'             '9'
# 392| 'in'            ''
# 393| '2372'          '2372'
# 394| ','             ','
# 395| 'he'            ''
# 396| 'briefly'       'briefly'
# 397| 'considered'    'considered'
# 398| 'resigning'     'resigning'
# 399| 'from'          ''
# 400| 'Starfleet'     'Starfleet'
# 401| 'Station'       'Station'
# 402| 'commander'     'commander'
# 403| 'Captain'       'Captain'
# 404| 'Benjamin'      'Benjamin'
# 405| 'Sisko'         'Sisko'
# 406| 'expressed'     'expressed'
# 407| 'regret'        'regret'
# 408| 'on'            ''
# 409| 'the'           ''
# 410| 'loss'          'loss'
# 411| 'of'            ''
# 412| 'the'           ''
# 413| 'Enterprise'    'Enterprise'
# 414| 'and'           ''
# 415| 'offered'       'offered'
# 416| 'his'           ''
# 417| 'condolences'   'condolences'
# 418| 'over'          ''
# 419| 'the'           ''
# 420| 'destruction'   'destruction'
# 421| 'of'            ''
# 422| 'the'           ''
# 423| 'ship'          'ship'
# 424| 'to'            ''
# 425| 'Worf'          'Worf'
# 426| ','             ','
# 427| 'saying'        'saying'
# 428| 'the'           ''
# 429| 'Enterprise'    'Enterprise'
# 430| 'was'           ''
# 431| 'a'             ''
# 432| 'good'          'good'
# 433| 'ship'          'ship'
# 434| '\n\n'          '\n\n'
# 435| 'Captain'       'Captain'
# 436| 'Picard'        'Picard'
# 437| "'s"            ''
# 438| 'belief'        'belief'
# 439| 'that'          ''
# 440| 'the'           ''
# 441| 'Enterprise'    'Enterprise'
# 442| '-'             '-'
# 443| 'D'             'D'
# 444| 'would'         ''
# 445| 'not'           ''
# 446| 'be'            ''
# 447| 'the'           ''
# 448| 'final'         'final'
# 449| 'ship'          'ship'
# 450| 'to'            ''
# 451| 'bear'          'bear'
# 452| 'the'           ''
# 453| 'name'          ''
# 454| 'was'           ''
# 455| 'borne'         'borne'
# 456| 'out'           ''
# 457| 'with'          ''
# 458| 'the'           ''
# 459| 'christening'   'christening'
# 460| 'of'            ''
# 461| 'the'           ''
# 462| 'Class'         'Class'
# 463| 'Sovereign'     'Sovereign'
# 464| 'USS'           'USS'
# 465| 'Enterprise'    'Enterprise'
# 466| 'NCC-1701'      'NCC-1701'
# 467| '-'             '-'
# 468| 'E'             'E'
# 469| ','             ','
# 470| 'later'         'later'
# 471| 'the'           ''
# 472| 'same'          ''
# 473| 'year'          'year'
# 474| 'In'            ''
# 475| 'that'          ''
# 476| 'instance'      'instance'
# 477| ','             ','
# 478| 'the'           ''
# 479| 'legacy'        'legacy'
# 480| 'of'            ''
# 481| 'the'           ''
# 482| 'Enterprise'    'Enterprise'
# 483| 'continued'     'continued'
# 484| 'with'          ''
# 485| 'Picard'        'Picard'
# 486| 'reprising'     'reprising'
# 487| 'his'           ''
# 488| 'role'          'role'
# 489| 'as'            ''
# 490| 'CO'            'CO'
# 491| 'and'           ''
# 492| 'selecting'     'selecting'
# 493| 'most'          ''
# 494| 'of'            ''
# 495| 'the'           ''
# 496| 'former'        ''
# 497| 'crew'          'crew'
# 498| 'from'          ''
# 499| 'the'           ''
# 500| 'Enterprise'    'Enterprise'
# 501| '-'             '-'
# 502| 'D'             'D'
# 503| ','             ','
# 504| 'with'          ''
# 505| 'the'           ''
# 506| 'notable'       'notable'
# 507| 'exception'     'exception'
# 508| 'of'            ''
# 509| 'Worf'          'Worf'
# 510| 'due'           ''
# 511| 'to'            ''
# 512| 'his'           ''
# 513| 'most'          ''
# 514| 'recent'        'recent'
# 515| 'assignment'    'assignment'
# 516| 'to'            ''
# 517| 'DS9'           'DS9'
# 518| '('             '('
# 519| 'though'        ''
# 520| 'he'            ''
# 521| 'temporarily'   'temporarily'
# 522| 'joined'        'joined'
# 523| 'the'           ''
# 524| 'Enterprise'    'Enterprise'
# 525| '-'             '-'
# 526| 'E'             'E'
# 527| 'crew'          'crew'
# 528| 'on'            ''
# 529| 'several'       ''
# 530| 'of'            ''
# 531| 'their'         ''
# 532| 'more'          ''
# 533| 'notable'       'notable'
# 534| 'missions'      'missions'
# 535| ')'             ')'

# %%
plot_words(['%r' % t.text for t in doc if not (t.is_stop | t.is_punct)])

# %% [markdown]
# ### Check Part of Speech

# %%
## spaCy
for i, t in enumerate(doc):
    print('%2d|%-12r : %-5s %s' % (i+1, t.text, t.pos_, t.tag_))
    if t.text == '.':
        break
# Out:
#  1|'USS'        : PROPN NNP
#  2|'Enterprise' : PROPN NNP
#  3|'('          : PUNCT -LRB-
#  4|'NCC-1701'   : PROPN NNP
#  5|'-'          : PUNCT HYPH
#  6|'D'          : NOUN  NN
#  7|')'          : PUNCT -RRB-
#  8|'\n\n'       : SPACE _SP
#  9|'For'        : ADP   IN
# 10|'five'       : NUM   CD
# 11|'hundred'    : NUM   CD
# 12|'years'      : NOUN  NNS
# 13|','          : PUNCT ,
# 14|'every'      : DET   DT
# 15|'ship'       : NOUN  NN
# 16|'that'       : PRON  WDT
# 17|'has'        : AUX   VBZ
# 18|'borne'      : VERB  VBN
# 19|'the'        : DET   DT
# 20|'name'       : NOUN  NN
# 21|'of'         : ADP   IN
# 22|'the'        : DET   DT
# 23|'Enterprise' : PROPN NNP
# 24|'has'        : AUX   VBZ
# 25|'become'     : VERB  VBN
# 26|'a'          : DET   DT
# 27|'legend'     : NOUN  NN
# 28|'This'       : DET   DT
# 29|'one'        : NOUN  NN
# 30|'is'         : AUX   VBZ
# 31|'no'         : DET   DT
# 32|'different'  : ADJ   JJ
# 33|'\n\n'       : SPACE _SP
# 34|'The'        : DET   DT
# 35|'USS'        : PROPN NNP
# 36|'Enterprise' : PROPN NNP
# 37|'('          : PUNCT -LRB-
# 38|'NCC-1701'   : PROPN NNP
# 39|'-'          : PUNCT HYPH
# 40|'D'          : NOUN  NN
# 41|')'          : PUNCT -RRB-
# 42|'was'        : AUX   VBD
# 43|'a'          : DET   DT
# 44|'24th'       : ADJ   JJ
# 45|'century'    : NOUN  NN
# 46|'United'     : PROPN NNP
# 47|'Federation' : PROPN NNP
# 48|'of'         : ADP   IN
# 49|'Planets'    : PROPN NNPS
# 50|'Galaxy'     : PROPN NNP
# 51|'Class'      : PROPN NNP
# 52|'starship'   : NOUN  NN
# 53|'operated'   : VERB  VBN
# 54|'by'         : ADP   IN
# 55|'Starfleet'  : PROPN NNP
# 56|','          : PUNCT ,
# 57|'and'        : CCONJ CC
# 58|'the'        : DET   DT
# 59|'fifth'      : PROPN NNP
# 60|'Federation' : PROPN NNP
# 61|'ship'       : NOUN  NN
# 62|'to'         : PART  TO
# 63|'bear'       : VERB  VB
# 64|'the'        : DET   DT
# 65|'name'       : NOUN  NN
# 66|'Enterprise' : NOUN  NN
# 67|'During'     : ADP   IN
# 68|'her'        : PRON  PRP$
# 69|'career'     : NOUN  NN
# 70|','          : PUNCT ,
# 71|'the'        : DET   DT
# 72|'Enterprise' : NOUN  NN
# 73|'served'     : VERB  VBD
# 74|'as'         : ADP   IN
# 75|'the'        : DET   DT
# 76|'Federation' : PROPN NNP
# 77|'flagship'   : NOUN  NN
# 78|'The'        : DET   DT
# 79|'Enterprise' : PROPN NNP
# 80|'was'        : AUX   VBD
# 81|'destroyed'  : VERB  VBN
# 82|'during'     : ADP   IN
# 83|'the'        : DET   DT
# 84|'Battle'     : PROPN NNP
# 85|'of'         : ADP   IN
# 86|'Veridian'   : PROPN NNP
# 87|'III'        : PROPN NNP
# 88|'in'         : ADP   IN
# 89|'2371'       : NUM   CD
# 90|'\n\n'       : SPACE _SP
# 91|'History'    : NOUN  NN
# 92|'\n'         : SPACE _SP
# 93|'Construction' : NOUN  NN
# 94|'and'        : CCONJ CC
# 95|'launch'     : NOUN  NN
# 96|'\n'         : SPACE _SP
# 97|'The'        : DET   DT
# 98|'Enterprise' : NOUN  NN
# 99|'was'        : AUX   VBD
# 100|'built'      : VERB  VBN
# 101|'at'         : ADP   IN
# 102|'Utopia'     : PROPN NNP
# 103|'Planitia'   : PROPN NNP
# 104|'Fleet'      : PROPN NNP
# 105|'Yards'      : PROPN NNP
# 106|'orbiting'   : VERB  VBG
# 107|'Mars'       : PROPN NNP
# 108|'in'         : ADP   IN
# 109|'the'        : DET   DT
# 110|'Solar'      : PROPN NNP
# 111|'system'     : NOUN  NN
# 112|'The'        : DET   DT
# 113|'construction' : NOUN  NN
# 114|'was'        : AUX   VBD
# 115|'a'          : DET   DT
# 116|'massive'    : ADJ   JJ
# 117|'undertaking' : NOUN  NN
# 118|','          : PUNCT ,
# 119|'involving'  : VERB  VBG
# 120|'thousands'  : NOUN  NNS
# 121|'of'         : ADP   IN
# 122|'people'     : NOUN  NNS
# 123|'across'     : ADP   IN
# 124|'disciplines' : NOUN  NNS
# 125|'Construction' : NOUN  NN
# 126|'was'        : AUX   VBD
# 127|'supervised' : VERB  VBN
# 128|'by'         : ADP   IN
# 129|'Commander'  : PROPN NNP
# 130|'Orfil'      : PROPN NNP
# 131|'Quinteros'  : PROPN NNP
# 132|'Dr'         : PROPN NNP
# 133|'Leah'       : PROPN NNP
# 134|'Brahms'     : PROPN NNP
# 135|'was'        : AUX   VBD
# 136|'responsible' : ADJ   JJ
# 137|'for'        : ADP   IN
# 138|'much'       : ADJ   JJ
# 139|'of'         : ADP   IN
# 140|'the'        : DET   DT
# 141|'Enterprise' : NOUN  NN
# 142|"'s"         : PART  POS
# 143|'warp'       : ADJ   JJ
# 144|'propulsion' : NOUN  NN
# 145|'system'     : NOUN  NN
# 146|'design'     : VERB  VB
# 147|'Some'       : PRON  DT
# 148|'of'         : ADP   IN
# 149|'the'        : DET   DT
# 150|'Enterprise' : NOUN  NN
# 151|"'s"         : PART  POS
# 152|'components' : NOUN  NNS
# 153|'were'       : AUX   VBD
# 154|'derived'    : VERB  VBN
# 155|'from'       : ADP   IN
# 156|'technology' : NOUN  NN
# 157|'originally' : ADV   RB
# 158|'developed'  : VERB  VBN
# 159|'on'         : ADP   IN
# 160|'the'        : DET   DT
# 161|'USS'        : PROPN NNP
# 162|'Pegasus'    : PROPN NNP
# 163|'\n\n'       : SPACE _SP
# 164|'One'        : NUM   CD
# 165|'of'         : ADP   IN
# 166|'the'        : DET   DT
# 167|'ship'       : NOUN  NN
# 168|"'s"         : PART  POS
# 169|'nacelle'    : NOUN  NN
# 170|'tube'       : NOUN  NN
# 171|'was'        : AUX   VBD
# 172|'the'        : DET   DT
# 173|'site'       : NOUN  NN
# 174|'of'         : ADP   IN
# 175|'a'          : DET   DT
# 176|'multiple'   : ADJ   JJ
# 177|'murder'     : NOUN  NN
# 178|'-'          : PUNCT HYPH
# 179|'suicide'    : NOUN  NN
# 180|'while'      : SCONJ IN
# 181|'she'        : PRON  PRP
# 182|'was'        : AUX   VBD
# 183|'still'      : ADV   RB
# 184|'under'      : ADP   IN
# 185|'construction' : NOUN  NN
# 186|'at'         : ADP   IN
# 187|'Utopia'     : PROPN NNP
# 188|'Planitia'   : PROPN NNP
# 189|'A'          : DET   DT
# 190|'member'     : NOUN  NN
# 191|'of'         : ADP   IN
# 192|'the'        : DET   DT
# 193|'construction' : NOUN  NN
# 194|'team'       : NOUN  NN
# 195|','          : PUNCT ,
# 196|'Walter'     : PROPN NNP
# 197|'Pierce'     : PROPN NNP
# 198|','          : PUNCT ,
# 199|'became'     : VERB  VBD
# 200|'jealous'    : ADJ   JJ
# 201|'of'         : ADP   IN
# 202|'a'          : DET   DT
# 203|'former'     : ADJ   JJ
# 204|'lover'      : NOUN  NN
# 205|"'s"         : PART  POS
# 206|'new'        : ADJ   JJ
# 207|'relationship' : NOUN  NN
# 208|'He'         : PRON  PRP
# 209|'killed'     : VERB  VBD
# 210|'the'        : DET   DT
# 211|'two'        : NUM   CD
# 212|'officers'   : NOUN  NNS
# 213|','          : PUNCT ,
# 214|'Marla'      : PROPN NNP
# 215|'Finn'       : PROPN NNP
# 216|'and'        : CCONJ CC
# 217|'William'    : PROPN NNP
# 218|'Hodges'     : PROPN NNP
# 219|','          : PUNCT ,
# 220|'then'       : ADV   RB
# 221|'disposed'   : VERB  VBN
# 222|'of'         : ADP   IN
# 223|'their'      : PRON  PRP$
# 224|'bodies'     : NOUN  NNS
# 225|'in'         : ADP   IN
# 226|'the'        : DET   DT
# 227|'plasma'     : NOUN  NN
# 228|'stream'     : NOUN  NN
# 229|'Pierce'     : PROPN NNP
# 230|'committed'  : VERB  VBD
# 231|'suicide'    : NOUN  NN
# 232|'in'         : ADP   IN
# 233|'the'        : DET   DT
# 234|'same'       : ADJ   JJ
# 235|'manner'     : NOUN  NN
# 236|','          : PUNCT ,
# 237|'leaving'    : VERB  VBG
# 238|'a'          : DET   DT
# 239|'telepathic' : ADJ   JJ
# 240|'imprint'    : NOUN  NN
# 241|'in'         : ADP   IN
# 242|'a'          : DET   DT
# 243|'bulkhead'   : NOUN  NN
# 244|'that'       : PRON  WDT
# 245|'was'        : AUX   VBD
# 246|'not'        : PART  RB
# 247|'discovered' : VERB  VBN
# 248|'until'      : ADP   IN
# 249|'2370'       : NUM   CD
# 250|'\n\n'       : SPACE _SP
# 251|'On'         : ADP   IN
# 252|'stardate'   : ADJ   JJ
# 253|'407595'     : NUM   CD
# 254|','          : PUNCT ,
# 255|'in'         : ADP   IN
# 256|'the'        : DET   DT
# 257|'year'       : NOUN  NN
# 258|'2363'       : NUM   CD
# 259|','          : PUNCT ,
# 260|'the'        : DET   DT
# 261|'Enterprise' : NOUN  NN
# 262|'was'        : AUX   VBD
# 263|'launched'   : VERB  VBN
# 264|'from'       : ADP   IN
# 265|'Mars'       : PROPN NNP
# 266|'On'         : ADP   IN
# 267|'stardate'   : ADJ   JJ
# 268|'410255'     : NUM   CD
# 269|','          : PUNCT ,
# 270|'the'        : DET   DT
# 271|'Enterprise' : NOUN  NN
# 272|'was'        : AUX   VBD
# 273|'commissioned' : VERB  VBN
# 274|'\n\n'       : SPACE _SP
# 275|'These'      : DET   DT
# 276|'stardates'  : NOUN  NNS
# 277|'were'       : AUX   VBD
# 278|"n't"        : PART  RB
# 279|'mentioned'  : VERB  VBN
# 280|'in'         : ADP   IN
# 281|'dialog'     : NOUN  NN
# 282|';'          : PUNCT :
# 283|'they'       : PRON  PRP
# 284|'were'       : AUX   VBD
# 285|'from'       : ADP   IN
# 286|'the'        : DET   DT
# 287|'Enterprise' : PROPN NNP
# 288|'dedication' : NOUN  NN
# 289|'plaque'     : NOUN  NN
# 290|'\n\n'       : SPACE _SP
# 291|'Final'      : ADJ   JJ
# 292|'systems'    : NOUN  NNS
# 293|'completion' : NOUN  NN
# 294|'and'        : CCONJ CC
# 295|'shakedown'  : NOUN  NN
# 296|'was'        : AUX   VBD
# 297|'conducted'  : VERB  VBN
# 298|'at'         : ADP   IN
# 299|'Earth'      : PROPN NNP
# 300|'Station'    : PROPN NNP
# 301|'McKinley'   : PROPN NNP
# 302|'Captain'    : PROPN NNP
# 303|'Jean'       : PROPN NNP
# 304|'-'          : PUNCT HYPH
# 305|'Luc'        : PROPN NNP
# 306|'Picard'     : PROPN NNP
# 307|'took'       : VERB  VBD
# 308|'command'    : NOUN  NN
# 309|'of'         : ADP   IN
# 310|'the'        : DET   DT
# 311|'ship'       : NOUN  NN
# 312|'on'         : ADP   IN
# 313|'stardate'   : NOUN  NN
# 314|'41148'      : NUM   CD
# 315|'at'         : ADP   IN
# 316|'the'        : DET   DT
# 317|'order'      : NOUN  NN
# 318|'of'         : ADP   IN
# 319|'Rear'       : PROPN NNP
# 320|'Admiral'    : PROPN NNP
# 321|'Norah'      : PROPN NNP
# 322|'Satie'      : PROPN NNP
# 323|'\n\n'       : SPACE _SP
# 324|'Legacy'     : PROPN NNP
# 325|'\n'         : SPACE _SP
# 326|'Commander'  : PROPN NNP
# 327|'Riker'      : PROPN NNP
# 328|'was'        : AUX   VBD
# 329|'upset'      : ADJ   JJ
# 330|'over'       : ADP   IN
# 331|'the'        : DET   DT
# 332|'loss'       : NOUN  NN
# 333|'of'         : ADP   IN
# 334|'the'        : DET   DT
# 335|'Enterprise' : NOUN  NN
# 336|'Having'     : AUX   VBG
# 337|'hoped'      : VERB  VBN
# 338|'he'         : PRON  PRP
# 339|'would'      : AUX   MD
# 340|'one'        : NUM   CD
# 341|'day'        : NOUN  NN
# 342|'command'    : VERB  VB
# 343|'the'        : DET   DT
# 344|'ship'       : NOUN  NN
# 345|','          : PUNCT ,
# 346|'he'         : PRON  PRP
# 347|'was'        : AUX   VBD
# 348|'disappointed' : VERB  VBN
# 349|'that'       : SCONJ IN
# 350|'he'         : PRON  PRP
# 351|'never'      : ADV   RB
# 352|'got'        : VERB  VBD
# 353|'that'       : DET   DT
# 354|'opportunity' : NOUN  NN
# 355|'However'    : ADV   RB
# 356|','          : PUNCT ,
# 357|'Picard'     : PROPN NNP
# 358|'expressed'  : VERB  VBD
# 359|'doubt'      : NOUN  NN
# 360|'that'       : SCONJ IN
# 361|'the'        : DET   DT
# 362|'Enterprise' : PROPN NNP
# 363|'-'          : PUNCT HYPH
# 364|'D'          : PROPN NNP
# 365|'would'      : AUX   MD
# 366|'be'         : AUX   VB
# 367|'the'        : DET   DT
# 368|'last'       : ADJ   JJ
# 369|'vessel'     : NOUN  NN
# 370|'to'         : PART  TO
# 371|'carry'      : VERB  VB
# 372|'the'        : DET   DT
# 373|'name'       : NOUN  NN
# 374|'\n\n'       : SPACE _SP
# 375|'The'        : DET   DT
# 376|'Enterprise' : NOUN  NN
# 377|'was'        : AUX   VBD
# 378|'so'         : ADV   RB
# 379|'dear'       : ADJ   JJ
# 380|'to'         : ADP   IN
# 381|'Worf'       : PROPN NNP
# 382|'that'       : PRON  DT
# 383|','          : PUNCT ,
# 384|'shortly'    : ADV   RB
# 385|'after'      : ADP   IN
# 386|'being'      : AUX   VBG
# 387|'reassigned' : VERB  VBN
# 388|'to'         : ADP   IN
# 389|'Deep'       : PROPN NNP
# 390|'Space'      : PROPN NNP
# 391|'9'          : NUM   CD
# 392|'in'         : ADP   IN
# 393|'2372'       : NUM   CD
# 394|','          : PUNCT ,
# 395|'he'         : PRON  PRP
# 396|'briefly'    : ADV   RB
# 397|'considered' : VERB  VBD
# 398|'resigning'  : VERB  VBG
# 399|'from'       : ADP   IN
# 400|'Starfleet'  : PROPN NNP
# 401|'Station'    : PROPN NNP
# 402|'commander'  : NOUN  NN
# 403|'Captain'    : PROPN NNP
# 404|'Benjamin'   : PROPN NNP
# 405|'Sisko'      : PROPN NNP
# 406|'expressed'  : VERB  VBD
# 407|'regret'     : NOUN  NN
# 408|'on'         : ADP   IN
# 409|'the'        : DET   DT
# 410|'loss'       : NOUN  NN
# 411|'of'         : ADP   IN
# 412|'the'        : DET   DT
# 413|'Enterprise' : NOUN  NN
# 414|'and'        : CCONJ CC
# 415|'offered'    : VERB  VBD
# 416|'his'        : PRON  PRP$
# 417|'condolences' : NOUN  NNS
# 418|'over'       : ADP   IN
# 419|'the'        : DET   DT
# 420|'destruction' : NOUN  NN
# 421|'of'         : ADP   IN
# 422|'the'        : DET   DT
# 423|'ship'       : NOUN  NN
# 424|'to'         : ADP   IN
# 425|'Worf'       : PROPN NNP
# 426|','          : PUNCT ,
# 427|'saying'     : VERB  VBG
# 428|'the'        : DET   DT
# 429|'Enterprise' : NOUN  NN
# 430|'was'        : AUX   VBD
# 431|'a'          : DET   DT
# 432|'good'       : ADJ   JJ
# 433|'ship'       : NOUN  NN
# 434|'\n\n'       : SPACE _SP
# 435|'Captain'    : PROPN NNP
# 436|'Picard'     : PROPN NNP
# 437|"'s"         : PART  POS
# 438|'belief'     : NOUN  NN
# 439|'that'       : SCONJ IN
# 440|'the'        : DET   DT
# 441|'Enterprise' : PROPN NNP
# 442|'-'          : PUNCT HYPH
# 443|'D'          : PROPN NNP
# 444|'would'      : AUX   MD
# 445|'not'        : PART  RB
# 446|'be'         : AUX   VB
# 447|'the'        : DET   DT
# 448|'final'      : ADJ   JJ
# 449|'ship'       : NOUN  NN
# 450|'to'         : PART  TO
# 451|'bear'       : VERB  VB
# 452|'the'        : DET   DT
# 453|'name'       : NOUN  NN
# 454|'was'        : AUX   VBD
# 455|'borne'      : VERB  VBN
# 456|'out'        : ADP   RP
# 457|'with'       : ADP   IN
# 458|'the'        : DET   DT
# 459|'christening' : NOUN  NN
# 460|'of'         : ADP   IN
# 461|'the'        : DET   DT
# 462|'Class'      : PROPN NNP
# 463|'Sovereign'  : PROPN NNP
# 464|'USS'        : PROPN NNP
# 465|'Enterprise' : PROPN NNP
# 466|'NCC-1701'   : PROPN NNP
# 467|'-'          : PUNCT HYPH
# 468|'E'          : NOUN  NN
# 469|','          : PUNCT ,
# 470|'later'      : ADV   RB
# 471|'the'        : DET   DT
# 472|'same'       : ADJ   JJ
# 473|'year'       : NOUN  NN
# 474|'In'         : ADP   IN
# 475|'that'       : DET   DT
# 476|'instance'   : NOUN  NN
# 477|','          : PUNCT ,
# 478|'the'        : DET   DT
# 479|'legacy'     : NOUN  NN
# 480|'of'         : ADP   IN
# 481|'the'        : DET   DT
# 482|'Enterprise' : NOUN  NN
# 483|'continued'  : VERB  VBD
# 484|'with'       : ADP   IN
# 485|'Picard'     : PROPN NNP
# 486|'reprising'  : VERB  VBG
# 487|'his'        : PRON  PRP$
# 488|'role'       : NOUN  NN
# 489|'as'         : ADP   IN
# 490|'CO'         : PROPN NNP
# 491|'and'        : CCONJ CC
# 492|'selecting'  : VERB  VBG
# 493|'most'       : ADJ   JJS
# 494|'of'         : ADP   IN
# 495|'the'        : DET   DT
# 496|'former'     : ADJ   JJ
# 497|'crew'       : NOUN  NN
# 498|'from'       : ADP   IN
# 499|'the'        : DET   DT
# 500|'Enterprise' : PROPN NNP
# 501|'-'          : PUNCT HYPH
# 502|'D'          : PROPN NNP
# 503|','          : PUNCT ,
# 504|'with'       : ADP   IN
# 505|'the'        : DET   DT
# 506|'notable'    : ADJ   JJ
# 507|'exception'  : NOUN  NN
# 508|'of'         : ADP   IN
# 509|'Worf'       : PROPN NNP
# 510|'due'        : ADP   IN
# 511|'to'         : ADP   IN
# 512|'his'        : PRON  PRP$
# 513|'most'       : ADV   RBS
# 514|'recent'     : ADJ   JJ
# 515|'assignment' : NOUN  NN
# 516|'to'         : ADP   IN
# 517|'DS9'        : PROPN NNP
# 518|'('          : PUNCT -LRB-
# 519|'though'     : SCONJ IN
# 520|'he'         : PRON  PRP
# 521|'temporarily' : ADV   RB
# 522|'joined'     : VERB  VBD
# 523|'the'        : DET   DT
# 524|'Enterprise' : PROPN NNP
# 525|'-'          : PUNCT HYPH
# 526|'E'          : NOUN  NN
# 527|'crew'       : NOUN  NN
# 528|'on'         : ADP   IN
# 529|'several'    : ADJ   JJ
# 530|'of'         : ADP   IN
# 531|'their'      : PRON  PRP$
# 532|'more'       : ADV   RBR
# 533|'notable'    : ADJ   JJ
# 534|'missions'   : NOUN  NNS
# 535|')'          : PUNCT -RRB-

# %% [markdown]
# ### Lemmatisation

# %%
## spaCy
print('i | Token        Lemma')
print('--| ------------ ------------')
for i, t in enumerate(doc):
    print('%2d| %-12r %r' % (i+1, t.text, t.lemma_))
    if t.text == '.':
        break
# Out:
# i | Token        Lemma
# --| ------------ ------------
#  1| 'USS'        'USS'
#  2| 'Enterprise' 'Enterprise'
#  3| '('          '('
#  4| 'NCC-1701'   'NCC-1701'
#  5| '-'          '-'
#  6| 'D'          'd'
#  7| ')'          ')'
#  8| '\n\n'       '\n\n'
#  9| 'For'        'for'
# 10| 'five'       'five'
# 11| 'hundred'    'hundred'
# 12| 'years'      'year'
# 13| ','          ','
# 14| 'every'      'every'
# 15| 'ship'       'ship'
# 16| 'that'       'that'
# 17| 'has'        'have'
# 18| 'borne'      'bear'
# 19| 'the'        'the'
# 20| 'name'       'name'
# 21| 'of'         'of'
# 22| 'the'        'the'
# 23| 'Enterprise' 'Enterprise'
# 24| 'has'        'have'
# 25| 'become'     'become'
# 26| 'a'          'a'
# 27| 'legend'     'legend'
# 28| 'This'       'this'
# 29| 'one'        'one'
# 30| 'is'         'be'
# 31| 'no'         'no'
# 32| 'different'  'different'
# 33| '\n\n'       '\n\n'
# 34| 'The'        'the'
# 35| 'USS'        'USS'
# 36| 'Enterprise' 'Enterprise'
# 37| '('          '('
# 38| 'NCC-1701'   'NCC-1701'
# 39| '-'          '-'
# 40| 'D'          'd'
# 41| ')'          ')'
# 42| 'was'        'be'
# 43| 'a'          'a'
# 44| '24th'       '24th'
# 45| 'century'    'century'
# 46| 'United'     'United'
# 47| 'Federation' 'Federation'
# 48| 'of'         'of'
# 49| 'Planets'    'Planets'
# 50| 'Galaxy'     'Galaxy'
# 51| 'Class'      'Class'
# 52| 'starship'   'starship'
# 53| 'operated'   'operate'
# 54| 'by'         'by'
# 55| 'Starfleet'  'Starfleet'
# 56| ','          ','
# 57| 'and'        'and'
# 58| 'the'        'the'
# 59| 'fifth'      'fifth'
# 60| 'Federation' 'Federation'
# 61| 'ship'       'ship'
# 62| 'to'         'to'
# 63| 'bear'       'bear'
# 64| 'the'        'the'
# 65| 'name'       'name'
# 66| 'Enterprise' 'enterprise'
# 67| 'During'     'during'
# 68| 'her'        'her'
# 69| 'career'     'career'
# 70| ','          ','
# 71| 'the'        'the'
# 72| 'Enterprise' 'enterprise'
# 73| 'served'     'serve'
# 74| 'as'         'as'
# 75| 'the'        'the'
# 76| 'Federation' 'Federation'
# 77| 'flagship'   'flagship'
# 78| 'The'        'the'
# 79| 'Enterprise' 'Enterprise'
# 80| 'was'        'be'
# 81| 'destroyed'  'destroy'
# 82| 'during'     'during'
# 83| 'the'        'the'
# 84| 'Battle'     'Battle'
# 85| 'of'         'of'
# 86| 'Veridian'   'Veridian'
# 87| 'III'        'III'
# 88| 'in'         'in'
# 89| '2371'       '2371'
# 90| '\n\n'       '\n\n'
# 91| 'History'    'history'
# 92| '\n'         '\n'
# 93| 'Construction' 'construction'
# 94| 'and'        'and'
# 95| 'launch'     'launch'
# 96| '\n'         '\n'
# 97| 'The'        'the'
# 98| 'Enterprise' 'enterprise'
# 99| 'was'        'be'
# 100| 'built'      'build'
# 101| 'at'         'at'
# 102| 'Utopia'     'Utopia'
# 103| 'Planitia'   'Planitia'
# 104| 'Fleet'      'Fleet'
# 105| 'Yards'      'Yards'
# 106| 'orbiting'   'orbit'
# 107| 'Mars'       'Mars'
# 108| 'in'         'in'
# 109| 'the'        'the'
# 110| 'Solar'      'Solar'
# 111| 'system'     'system'
# 112| 'The'        'the'
# 113| 'construction' 'construction'
# 114| 'was'        'be'
# 115| 'a'          'a'
# 116| 'massive'    'massive'
# 117| 'undertaking' 'undertaking'
# 118| ','          ','
# 119| 'involving'  'involve'
# 120| 'thousands'  'thousand'
# 121| 'of'         'of'
# 122| 'people'     'people'
# 123| 'across'     'across'
# 124| 'disciplines' 'discipline'
# 125| 'Construction' 'construction'
# 126| 'was'        'be'
# 127| 'supervised' 'supervise'
# 128| 'by'         'by'
# 129| 'Commander'  'Commander'
# 130| 'Orfil'      'Orfil'
# 131| 'Quinteros'  'Quinteros'
# 132| 'Dr'         'Dr'
# 133| 'Leah'       'Leah'
# 134| 'Brahms'     'Brahms'
# 135| 'was'        'be'
# 136| 'responsible' 'responsible'
# 137| 'for'        'for'
# 138| 'much'       'much'
# 139| 'of'         'of'
# 140| 'the'        'the'
# 141| 'Enterprise' 'enterprise'
# 142| "'s"         "'s"
# 143| 'warp'       'warp'
# 144| 'propulsion' 'propulsion'
# 145| 'system'     'system'
# 146| 'design'     'design'
# 147| 'Some'       'some'
# 148| 'of'         'of'
# 149| 'the'        'the'
# 150| 'Enterprise' 'enterprise'
# 151| "'s"         "'s"
# 152| 'components' 'component'
# 153| 'were'       'be'
# 154| 'derived'    'derive'
# 155| 'from'       'from'
# 156| 'technology' 'technology'
# 157| 'originally' 'originally'
# 158| 'developed'  'develop'
# 159| 'on'         'on'
# 160| 'the'        'the'
# 161| 'USS'        'USS'
# 162| 'Pegasus'    'Pegasus'
# 163| '\n\n'       '\n\n'
# 164| 'One'        'one'
# 165| 'of'         'of'
# 166| 'the'        'the'
# 167| 'ship'       'ship'
# 168| "'s"         "'s"
# 169| 'nacelle'    'nacelle'
# 170| 'tube'       'tube'
# 171| 'was'        'be'
# 172| 'the'        'the'
# 173| 'site'       'site'
# 174| 'of'         'of'
# 175| 'a'          'a'
# 176| 'multiple'   'multiple'
# 177| 'murder'     'murder'
# 178| '-'          '-'
# 179| 'suicide'    'suicide'
# 180| 'while'      'while'
# 181| 'she'        'she'
# 182| 'was'        'be'
# 183| 'still'      'still'
# 184| 'under'      'under'
# 185| 'construction' 'construction'
# 186| 'at'         'at'
# 187| 'Utopia'     'Utopia'
# 188| 'Planitia'   'Planitia'
# 189| 'A'          'a'
# 190| 'member'     'member'
# 191| 'of'         'of'
# 192| 'the'        'the'
# 193| 'construction' 'construction'
# 194| 'team'       'team'
# 195| ','          ','
# 196| 'Walter'     'Walter'
# 197| 'Pierce'     'Pierce'
# 198| ','          ','
# 199| 'became'     'become'
# 200| 'jealous'    'jealous'
# 201| 'of'         'of'
# 202| 'a'          'a'
# 203| 'former'     'former'
# 204| 'lover'      'lover'
# 205| "'s"         "'s"
# 206| 'new'        'new'
# 207| 'relationship' 'relationship'
# 208| 'He'         'he'
# 209| 'killed'     'kill'
# 210| 'the'        'the'
# 211| 'two'        'two'
# 212| 'officers'   'officer'
# 213| ','          ','
# 214| 'Marla'      'Marla'
# 215| 'Finn'       'Finn'
# 216| 'and'        'and'
# 217| 'William'    'William'
# 218| 'Hodges'     'Hodges'
# 219| ','          ','
# 220| 'then'       'then'
# 221| 'disposed'   'dispose'
# 222| 'of'         'of'
# 223| 'their'      'their'
# 224| 'bodies'     'body'
# 225| 'in'         'in'
# 226| 'the'        'the'
# 227| 'plasma'     'plasma'
# 228| 'stream'     'stream'
# 229| 'Pierce'     'Pierce'
# 230| 'committed'  'commit'
# 231| 'suicide'    'suicide'
# 232| 'in'         'in'
# 233| 'the'        'the'
# 234| 'same'       'same'
# 235| 'manner'     'manner'
# 236| ','          ','
# 237| 'leaving'    'leave'
# 238| 'a'          'a'
# 239| 'telepathic' 'telepathic'
# 240| 'imprint'    'imprint'
# 241| 'in'         'in'
# 242| 'a'          'a'
# 243| 'bulkhead'   'bulkhead'
# 244| 'that'       'that'
# 245| 'was'        'be'
# 246| 'not'        'not'
# 247| 'discovered' 'discover'
# 248| 'until'      'until'
# 249| '2370'       '2370'
# 250| '\n\n'       '\n\n'
# 251| 'On'         'on'
# 252| 'stardate'   'stardate'
# 253| '407595'     '407595'
# 254| ','          ','
# 255| 'in'         'in'
# 256| 'the'        'the'
# 257| 'year'       'year'
# 258| '2363'       '2363'
# 259| ','          ','
# 260| 'the'        'the'
# 261| 'Enterprise' 'enterprise'
# 262| 'was'        'be'
# 263| 'launched'   'launch'
# 264| 'from'       'from'
# 265| 'Mars'       'Mars'
# 266| 'On'         'on'
# 267| 'stardate'   'stardate'
# 268| '410255'     '410255'
# 269| ','          ','
# 270| 'the'        'the'
# 271| 'Enterprise' 'enterprise'
# 272| 'was'        'be'
# 273| 'commissioned' 'commission'
# 274| '\n\n'       '\n\n'
# 275| 'These'      'these'
# 276| 'stardates'  'stardate'
# 277| 'were'       'be'
# 278| "n't"        'not'
# 279| 'mentioned'  'mention'
# 280| 'in'         'in'
# 281| 'dialog'     'dialog'
# 282| ';'          ';'
# 283| 'they'       'they'
# 284| 'were'       'be'
# 285| 'from'       'from'
# 286| 'the'        'the'
# 287| 'Enterprise' 'Enterprise'
# 288| 'dedication' 'dedication'
# 289| 'plaque'     'plaque'
# 290| '\n\n'       '\n\n'
# 291| 'Final'      'final'
# 292| 'systems'    'system'
# 293| 'completion' 'completion'
# 294| 'and'        'and'
# 295| 'shakedown'  'shakedown'
# 296| 'was'        'be'
# 297| 'conducted'  'conduct'
# 298| 'at'         'at'
# 299| 'Earth'      'Earth'
# 300| 'Station'    'Station'
# 301| 'McKinley'   'McKinley'
# 302| 'Captain'    'Captain'
# 303| 'Jean'       'Jean'
# 304| '-'          '-'
# 305| 'Luc'        'Luc'
# 306| 'Picard'     'Picard'
# 307| 'took'       'take'
# 308| 'command'    'command'
# 309| 'of'         'of'
# 310| 'the'        'the'
# 311| 'ship'       'ship'
# 312| 'on'         'on'
# 313| 'stardate'   'stardate'
# 314| '41148'      '41148'
# 315| 'at'         'at'
# 316| 'the'        'the'
# 317| 'order'      'order'
# 318| 'of'         'of'
# 319| 'Rear'       'Rear'
# 320| 'Admiral'    'Admiral'
# 321| 'Norah'      'Norah'
# 322| 'Satie'      'Satie'
# 323| '\n\n'       '\n\n'
# 324| 'Legacy'     'Legacy'
# 325| '\n'         '\n'
# 326| 'Commander'  'Commander'
# 327| 'Riker'      'Riker'
# 328| 'was'        'be'
# 329| 'upset'      'upset'
# 330| 'over'       'over'
# 331| 'the'        'the'
# 332| 'loss'       'loss'
# 333| 'of'         'of'
# 334| 'the'        'the'
# 335| 'Enterprise' 'enterprise'
# 336| 'Having'     'having'
# 337| 'hoped'      'hope'
# 338| 'he'         'he'
# 339| 'would'      'would'
# 340| 'one'        'one'
# 341| 'day'        'day'
# 342| 'command'    'command'
# 343| 'the'        'the'
# 344| 'ship'       'ship'
# 345| ','          ','
# 346| 'he'         'he'
# 347| 'was'        'be'
# 348| 'disappointed' 'disappoint'
# 349| 'that'       'that'
# 350| 'he'         'he'
# 351| 'never'      'never'
# 352| 'got'        'get'
# 353| 'that'       'that'
# 354| 'opportunity' 'opportunity'
# 355| 'However'    'however'
# 356| ','          ','
# 357| 'Picard'     'Picard'
# 358| 'expressed'  'express'
# 359| 'doubt'      'doubt'
# 360| 'that'       'that'
# 361| 'the'        'the'
# 362| 'Enterprise' 'Enterprise'
# 363| '-'          '-'
# 364| 'D'          'D'
# 365| 'would'      'would'
# 366| 'be'         'be'
# 367| 'the'        'the'
# 368| 'last'       'last'
# 369| 'vessel'     'vessel'
# 370| 'to'         'to'
# 371| 'carry'      'carry'
# 372| 'the'        'the'
# 373| 'name'       'name'
# 374| '\n\n'       '\n\n'
# 375| 'The'        'the'
# 376| 'Enterprise' 'enterprise'
# 377| 'was'        'be'
# 378| 'so'         'so'
# 379| 'dear'       'dear'
# 380| 'to'         'to'
# 381| 'Worf'       'Worf'
# 382| 'that'       'that'
# 383| ','          ','
# 384| 'shortly'    'shortly'
# 385| 'after'      'after'
# 386| 'being'      'be'
# 387| 'reassigned' 'reassign'
# 388| 'to'         'to'
# 389| 'Deep'       'Deep'
# 390| 'Space'      'Space'
# 391| '9'          '9'
# 392| 'in'         'in'
# 393| '2372'       '2372'
# 394| ','          ','
# 395| 'he'         'he'
# 396| 'briefly'    'briefly'
# 397| 'considered' 'consider'
# 398| 'resigning'  'resign'
# 399| 'from'       'from'
# 400| 'Starfleet'  'Starfleet'
# 401| 'Station'    'Station'
# 402| 'commander'  'commander'
# 403| 'Captain'    'Captain'
# 404| 'Benjamin'   'Benjamin'
# 405| 'Sisko'      'Sisko'
# 406| 'expressed'  'express'
# 407| 'regret'     'regret'
# 408| 'on'         'on'
# 409| 'the'        'the'
# 410| 'loss'       'loss'
# 411| 'of'         'of'
# 412| 'the'        'the'
# 413| 'Enterprise' 'enterprise'
# 414| 'and'        'and'
# 415| 'offered'    'offer'
# 416| 'his'        'his'
# 417| 'condolences' 'condolence'
# 418| 'over'       'over'
# 419| 'the'        'the'
# 420| 'destruction' 'destruction'
# 421| 'of'         'of'
# 422| 'the'        'the'
# 423| 'ship'       'ship'
# 424| 'to'         'to'
# 425| 'Worf'       'Worf'
# 426| ','          ','
# 427| 'saying'     'say'
# 428| 'the'        'the'
# 429| 'Enterprise' 'enterprise'
# 430| 'was'        'be'
# 431| 'a'          'a'
# 432| 'good'       'good'
# 433| 'ship'       'ship'
# 434| '\n\n'       '\n\n'
# 435| 'Captain'    'Captain'
# 436| 'Picard'     'Picard'
# 437| "'s"         "'s"
# 438| 'belief'     'belief'
# 439| 'that'       'that'
# 440| 'the'        'the'
# 441| 'Enterprise' 'Enterprise'
# 442| '-'          '-'
# 443| 'D'          'D'
# 444| 'would'      'would'
# 445| 'not'        'not'
# 446| 'be'         'be'
# 447| 'the'        'the'
# 448| 'final'      'final'
# 449| 'ship'       'ship'
# 450| 'to'         'to'
# 451| 'bear'       'bear'
# 452| 'the'        'the'
# 453| 'name'       'name'
# 454| 'was'        'be'
# 455| 'borne'      'bear'
# 456| 'out'        'out'
# 457| 'with'       'with'
# 458| 'the'        'the'
# 459| 'christening' 'christening'
# 460| 'of'         'of'
# 461| 'the'        'the'
# 462| 'Class'      'Class'
# 463| 'Sovereign'  'Sovereign'
# 464| 'USS'        'USS'
# 465| 'Enterprise' 'Enterprise'
# 466| 'NCC-1701'   'NCC-1701'
# 467| '-'          '-'
# 468| 'E'          'e'
# 469| ','          ','
# 470| 'later'      'later'
# 471| 'the'        'the'
# 472| 'same'       'same'
# 473| 'year'       'year'
# 474| 'In'         'in'
# 475| 'that'       'that'
# 476| 'instance'   'instance'
# 477| ','          ','
# 478| 'the'        'the'
# 479| 'legacy'     'legacy'
# 480| 'of'         'of'
# 481| 'the'        'the'
# 482| 'Enterprise' 'enterprise'
# 483| 'continued'  'continue'
# 484| 'with'       'with'
# 485| 'Picard'     'Picard'
# 486| 'reprising'  'reprise'
# 487| 'his'        'his'
# 488| 'role'       'role'
# 489| 'as'         'as'
# 490| 'CO'         'CO'
# 491| 'and'        'and'
# 492| 'selecting'  'select'
# 493| 'most'       'most'
# 494| 'of'         'of'
# 495| 'the'        'the'
# 496| 'former'     'former'
# 497| 'crew'       'crew'
# 498| 'from'       'from'
# 499| 'the'        'the'
# 500| 'Enterprise' 'Enterprise'
# 501| '-'          '-'
# 502| 'D'          'D'
# 503| ','          ','
# 504| 'with'       'with'
# 505| 'the'        'the'
# 506| 'notable'    'notable'
# 507| 'exception'  'exception'
# 508| 'of'         'of'
# 509| 'Worf'       'Worf'
# 510| 'due'        'due'
# 511| 'to'         'to'
# 512| 'his'        'his'
# 513| 'most'       'most'
# 514| 'recent'     'recent'
# 515| 'assignment' 'assignment'
# 516| 'to'         'to'
# 517| 'DS9'        'DS9'
# 518| '('          '('
# 519| 'though'     'though'
# 520| 'he'         'he'
# 521| 'temporarily' 'temporarily'
# 522| 'joined'     'join'
# 523| 'the'        'the'
# 524| 'Enterprise' 'Enterprise'
# 525| '-'          '-'
# 526| 'E'          'e'
# 527| 'crew'       'crew'
# 528| 'on'         'on'
# 529| 'several'    'several'
# 530| 'of'         'of'
# 531| 'their'      'their'
# 532| 'more'       'more'
# 533| 'notable'    'notable'
# 534| 'missions'   'mission'
# 535| ')'          ')'

# %%
plot_words(['%r' % t.lemma_ for t in doc if not (t.is_stop | t.is_punct)])

# %% [markdown]
# ### Entity Recognition

# %%
## spaCy
for i, s in enumerate(doc.sents):
    print('%2d: %s' % (i, re.sub(r'\n+', '', s.text)))
    if s.as_doc().ents:
        print('-'*80)
        for e in s.as_doc().ents:
            print('%-11s: %s' % (e.label_, re.sub(r'\n+', '', e.text)))
    print('='*80)
# Out:
#  0: USS Enterprise (NCC-1701-D)For five hundred years, every ship that has borne the name of the Enterprise has become a legend
# --------------------------------------------------------------------------------
# DATE       : five hundred years
# ORG        : Enterprise
# ================================================================================
#  1: This one is no differentThe USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise During her career, the Enterprise served as the Federation flagship The Enterprise was destroyed during the Battle of Veridian III in 2371HistoryConstruction and launchThe Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system The construction was a massive undertaking, involving thousands of people across disciplines Construction was supervised by Commander Orfil Quinteros
# --------------------------------------------------------------------------------
# PRODUCT    : The USS Enterprise
# DATE       : a 24th century
# ORG        : United Federation of Planets Galaxy Class
# ORG        : Starfleet
# ORDINAL    : fifth
# ORG        : Enterprise
# EVENT      : the Battle of Veridian III
# DATE       : 2371
# ORG        : Utopia Planitia Fleet Yards
# LOC        : Mars
# PRODUCT    : Solar
# CARDINAL   : thousands
# PERSON     : Orfil Quinteros
# ================================================================================
#  2: Dr Leah Brahms was responsible for much of the Enterprise's warp propulsion system design Some of the Enterprise's components were derived from technology originally developed on the USS PegasusOne of the ship's nacelle tube was the site of a multiple murder-suicide while she was still under construction at Utopia Planitia
# --------------------------------------------------------------------------------
# PERSON     : Leah Brahms
# ORG        : Enterprise
# ORG        : Enterprise
# PRODUCT    : the USS PegasusOne
# PERSON     : nacelle tube
# ORG        : Utopia Planitia
# ================================================================================
#  3: A member of the construction team, Walter Pierce, became jealous of a former lover's new relationship He killed the two officers, Marla Finn and William Hodges, then disposed of their bodies in the plasma stream Pierce committed suicide in the same manner, leaving a telepathic imprint in a bulkhead that was not discovered until 2370On stardate 407595, in the year 2363, the Enterprise was launched from Mars On stardate 410255, the Enterprise was commissionedThese stardates weren't mentioned in dialog; they were from the Enterprise dedication plaqueFinal systems completion and shakedown was conducted at Earth Station McKinley Captain Jean-Luc Picard took command of the ship on stardate 41148 at the order of Rear Admiral Norah SatieLegacyCommander Riker was upset over the loss of the Enterprise Having hoped he would one day command the ship, he was disappointed that he never got that opportunity However, Picard expressed doubt that the Enterprise-D would be the last vessel to carry the nameThe Enterprise was so dear to Worf that, shortly after being reassigned to Deep Space 9 in 2372, he briefly considered resigning from Starfleet Station commander Captain Benjamin Sisko expressed regret on the loss of the Enterprise and offered his condolences over the destruction of the ship to Worf, saying the Enterprise was a good shipCaptain Picard's belief that the Enterprise-D would not be the final ship to bear the name was borne out with the christening of the Class Sovereign USS Enterprise NCC-1701-E, later the same year In that instance, the legacy of the Enterprise continued with Picard reprising his role as CO and selecting most of the former crew from the Enterprise-D, with the notable exception of Worf due to his most recent assignment to DS9 (though he temporarily joined the Enterprise-E crew on several of their more notable missions)
# --------------------------------------------------------------------------------
# PERSON     : Walter Pierce
# CARDINAL   : two
# PERSON     : Marla Finn
# PERSON     : William Hodges
# CARDINAL   : 2370
# DATE       : 407595
# DATE       : the year 2363
# LOC        : Mars
# DATE       : 410255
# ORG        : Enterprise
# LOC        : Earth Station McKinley
# PERSON     : Jean-Luc Picard
# DATE       : 41148
# ORG        : Rear Admiral
# PERSON     : Norah Satie
# PERSON     : Riker
# ORG        : the Enterprise Having
# FAC        : Deep Space 9
# DATE       : 2372
# ORG        : Starfleet Station
# PERSON     : Benjamin Sisko
# ORG        : Enterprise
# PERSON     : Picard
# DATE       : later the same year
# ORG        : CO
# ================================================================================

# %% [markdown]
# ## Extra: Using NLTK for NLP
#
# ### Tokenise

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/macbook/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# use nltk to find tokens
tokens = nltk.word_tokenize(text)

for i, t in enumerate(tokens[:25]):
    print('%2d| %r' % (i+1, t))
# Out:
#  1| 'USS'
#  2| 'Enterprise'
#  3| '('
#  4| 'NCC-1701-D'
#  5| ')'
#  6| 'For'
#  7| 'five'
#  8| 'hundred'
#  9| 'years'
# 10| ','
# 11| 'every'
# 12| 'ship'
# 13| 'that'
# 14| 'has'
# 15| 'borne'
# 16| 'the'
# 17| 'name'
# 18| 'of'
# 19| 'the'
# 20| 'Enterprise'
# 21| 'has'
# 22| 'become'
# 23| 'a'
# 24| 'legend'
# 25| 'This'

# %%
plot_words(tokens)

# %% [markdown]
# ### Stop words

# %%
stopWords = nltk.corpus.stopwords.words('english')

stopWords.sort()
print(', '.join(stopWords))
# Out:
# a, about, above, after, again, against, ain, all, am, an, and, any, are, aren, aren't, as, at, be, because, been, before, being, below, between, both, but, by, can, couldn, couldn't, d, did, didn, didn't, do, does, doesn, doesn't, doing, don, don't, down, during, each, few, for, from, further, had, hadn, hadn't, has, hasn, hasn't, have, haven, haven't, having, he, her, here, hers, herself, him, himself, his, how, i, if, in, into, is, isn, isn't, it, it's, its, itself, just, ll, m, ma, me, mightn, mightn't, more, most, mustn, mustn't, my, myself, needn, needn't, no, nor, not, now, o, of, off, on, once, only, or, other, our, ours, ourselves, out, over, own, re, s, same, shan, shan't, she, she's, should, should've, shouldn, shouldn't, so, some, such, t, than, that, that'll, the, their, theirs, them, themselves, then, there, these, they, this, those, through, to, too, under, until, up, ve, very, was, wasn, wasn't, we, were, weren, weren't, what, when, where, which, while, who, whom, why, will, with, won, won't, wouldn, wouldn't, y, you, you'd, you'll, you're, you've, your, yours, yourself, yourselves

# %%
# ANSWER
# NOTE: see the `.lower()` method applied to token
tokens_no_stop = [t for t in tokens if t.lower() not in stopWords]

# %%
## NLTK
i = 0
j = 0

print('i | with stop words without')
print('--| --------------- ------------')

# for all the tokens
while i < len(tokens):
    # same word
    if tokens[i] == tokens_no_stop[j]:
        print('%2d| %-15r %r' % (i+1, tokens[i], tokens_no_stop[j]))
        j += 1
    # not the same word
    else:
        print('%2d| %-15r' % (i+1, tokens[i]))

    # next word
    i += 1
    # break after the first sentence
    if tokens[i-1] == '.':
        break
# Out:
# i | with stop words without
# --| --------------- ------------
#  1| 'USS'           'USS'
#  2| 'Enterprise'    'Enterprise'
#  3| '('             '('
#  4| 'NCC-1701-D'    'NCC-1701-D'
#  5| ')'             ')'
#  6| 'For'
#  7| 'five'          'five'
#  8| 'hundred'       'hundred'
#  9| 'years'         'years'
# 10| ','             ','
# 11| 'every'         'every'
# 12| 'ship'          'ship'
# 13| 'that'
# 14| 'has'
# 15| 'borne'         'borne'
# 16| 'the'
# 17| 'name'          'name'
# 18| 'of'
# 19| 'the'
# 20| 'Enterprise'    'Enterprise'
# 21| 'has'
# 22| 'become'        'become'
# 23| 'a'
# 24| 'legend'        'legend'
# 25| 'This'
# 26| 'one'           'one'
# 27| 'is'
# 28| 'no'
# 29| 'different'     'different'
# 30| 'The'
# 31| 'USS'           'USS'
# 32| 'Enterprise'    'Enterprise'
# 33| '('             '('
# 34| 'NCC-1701-D'    'NCC-1701-D'
# 35| ')'             ')'
# 36| 'was'
# 37| 'a'
# 38| '24th'          '24th'
# 39| 'century'       'century'
# 40| 'United'        'United'
# 41| 'Federation'    'Federation'
# 42| 'of'
# 43| 'Planets'       'Planets'
# 44| 'Galaxy'        'Galaxy'
# 45| 'Class'         'Class'
# 46| 'starship'      'starship'
# 47| 'operated'      'operated'
# 48| 'by'
# 49| 'Starfleet'     'Starfleet'
# 50| ','             ','
# 51| 'and'
# 52| 'the'
# 53| 'fifth'         'fifth'
# 54| 'Federation'    'Federation'
# 55| 'ship'          'ship'
# 56| 'to'
# 57| 'bear'          'bear'
# 58| 'the'
# 59| 'name'          'name'
# 60| 'Enterprise'    'Enterprise'
# 61| 'During'
# 62| 'her'
# 63| 'career'        'career'
# 64| ','             ','
# 65| 'the'
# 66| 'Enterprise'    'Enterprise'
# 67| 'served'        'served'
# 68| 'as'
# 69| 'the'
# 70| 'Federation'    'Federation'
# 71| 'flagship'      'flagship'
# 72| 'The'
# 73| 'Enterprise'    'Enterprise'
# 74| 'was'
# 75| 'destroyed'     'destroyed'
# 76| 'during'
# 77| 'the'
# 78| 'Battle'        'Battle'
# 79| 'of'
# 80| 'Veridian'      'Veridian'
# 81| 'III'           'III'
# 82| 'in'
# 83| '2371'          '2371'
# 84| 'History'       'History'
# 85| 'Construction'  'Construction'
# 86| 'and'
# 87| 'launch'        'launch'
# 88| 'The'
# 89| 'Enterprise'    'Enterprise'
# 90| 'was'
# 91| 'built'         'built'
# 92| 'at'
# 93| 'Utopia'        'Utopia'
# 94| 'Planitia'      'Planitia'
# 95| 'Fleet'         'Fleet'
# 96| 'Yards'         'Yards'
# 97| 'orbiting'      'orbiting'
# 98| 'Mars'          'Mars'
# 99| 'in'
# 100| 'the'
# 101| 'Solar'         'Solar'
# 102| 'system'        'system'
# 103| 'The'
# 104| 'construction'  'construction'
# 105| 'was'
# 106| 'a'
# 107| 'massive'       'massive'
# 108| 'undertaking'   'undertaking'
# 109| ','             ','
# 110| 'involving'     'involving'
# 111| 'thousands'     'thousands'
# 112| 'of'
# 113| 'people'        'people'
# 114| 'across'        'across'
# 115| 'disciplines'   'disciplines'
# 116| 'Construction'  'Construction'
# 117| 'was'
# 118| 'supervised'    'supervised'
# 119| 'by'
# 120| 'Commander'     'Commander'
# 121| 'Orfil'         'Orfil'
# 122| 'Quinteros'     'Quinteros'
# 123| 'Dr'            'Dr'
# 124| 'Leah'          'Leah'
# 125| 'Brahms'        'Brahms'
# 126| 'was'
# 127| 'responsible'   'responsible'
# 128| 'for'
# 129| 'much'          'much'
# 130| 'of'
# 131| 'the'
# 132| 'Enterprise'    'Enterprise'
# 133| "'s"            "'s"
# 134| 'warp'          'warp'
# 135| 'propulsion'    'propulsion'
# 136| 'system'        'system'
# 137| 'design'        'design'
# 138| 'Some'
# 139| 'of'
# 140| 'the'
# 141| 'Enterprise'    'Enterprise'
# 142| "'s"            "'s"
# 143| 'components'    'components'
# 144| 'were'
# 145| 'derived'       'derived'
# 146| 'from'
# 147| 'technology'    'technology'
# 148| 'originally'    'originally'
# 149| 'developed'     'developed'
# 150| 'on'
# 151| 'the'
# 152| 'USS'           'USS'
# 153| 'Pegasus'       'Pegasus'
# 154| 'One'           'One'
# 155| 'of'
# 156| 'the'
# 157| 'ship'          'ship'
# 158| "'s"            "'s"
# 159| 'nacelle'       'nacelle'
# 160| 'tube'          'tube'
# 161| 'was'
# 162| 'the'
# 163| 'site'          'site'
# 164| 'of'
# 165| 'a'
# 166| 'multiple'      'multiple'
# 167| 'murder-suicide' 'murder-suicide'
# 168| 'while'
# 169| 'she'
# 170| 'was'
# 171| 'still'         'still'
# 172| 'under'
# 173| 'construction'  'construction'
# 174| 'at'
# 175| 'Utopia'        'Utopia'
# 176| 'Planitia'      'Planitia'
# 177| 'A'
# 178| 'member'        'member'
# 179| 'of'
# 180| 'the'
# 181| 'construction'  'construction'
# 182| 'team'          'team'
# 183| ','             ','
# 184| 'Walter'        'Walter'
# 185| 'Pierce'        'Pierce'
# 186| ','             ','
# 187| 'became'        'became'
# 188| 'jealous'       'jealous'
# 189| 'of'
# 190| 'a'
# 191| 'former'        'former'
# 192| 'lover'         'lover'
# 193| "'s"            "'s"
# 194| 'new'           'new'
# 195| 'relationship'  'relationship'
# 196| 'He'
# 197| 'killed'        'killed'
# 198| 'the'
# 199| 'two'           'two'
# 200| 'officers'      'officers'
# 201| ','             ','
# 202| 'Marla'         'Marla'
# 203| 'Finn'          'Finn'
# 204| 'and'
# 205| 'William'       'William'
# 206| 'Hodges'        'Hodges'
# 207| ','             ','
# 208| 'then'
# 209| 'disposed'      'disposed'
# 210| 'of'
# 211| 'their'
# 212| 'bodies'        'bodies'
# 213| 'in'
# 214| 'the'
# 215| 'plasma'        'plasma'
# 216| 'stream'        'stream'
# 217| 'Pierce'        'Pierce'
# 218| 'committed'     'committed'
# 219| 'suicide'       'suicide'
# 220| 'in'
# 221| 'the'
# 222| 'same'
# 223| 'manner'        'manner'
# 224| ','             ','
# 225| 'leaving'       'leaving'
# 226| 'a'
# 227| 'telepathic'    'telepathic'
# 228| 'imprint'       'imprint'
# 229| 'in'
# 230| 'a'
# 231| 'bulkhead'      'bulkhead'
# 232| 'that'
# 233| 'was'
# 234| 'not'
# 235| 'discovered'    'discovered'
# 236| 'until'
# 237| '2370'          '2370'
# 238| 'On'
# 239| 'stardate'      'stardate'
# 240| '407595'        '407595'
# 241| ','             ','
# 242| 'in'
# 243| 'the'
# 244| 'year'          'year'
# 245| '2363'          '2363'
# 246| ','             ','
# 247| 'the'
# 248| 'Enterprise'    'Enterprise'
# 249| 'was'
# 250| 'launched'      'launched'
# 251| 'from'
# 252| 'Mars'          'Mars'
# 253| 'On'
# 254| 'stardate'      'stardate'
# 255| '410255'        '410255'
# 256| ','             ','
# 257| 'the'
# 258| 'Enterprise'    'Enterprise'
# 259| 'was'
# 260| 'commissioned'  'commissioned'
# 261| 'These'
# 262| 'stardates'     'stardates'
# 263| 'were'
# 264| "n't"           "n't"
# 265| 'mentioned'     'mentioned'
# 266| 'in'
# 267| 'dialog'        'dialog'
# 268| ';'             ';'
# 269| 'they'
# 270| 'were'
# 271| 'from'
# 272| 'the'
# 273| 'Enterprise'    'Enterprise'
# 274| 'dedication'    'dedication'
# 275| 'plaque'        'plaque'
# 276| 'Final'         'Final'
# 277| 'systems'       'systems'
# 278| 'completion'    'completion'
# 279| 'and'
# 280| 'shakedown'     'shakedown'
# 281| 'was'
# 282| 'conducted'     'conducted'
# 283| 'at'
# 284| 'Earth'         'Earth'
# 285| 'Station'       'Station'
# 286| 'McKinley'      'McKinley'
# 287| 'Captain'       'Captain'
# 288| 'Jean-Luc'      'Jean-Luc'
# 289| 'Picard'        'Picard'
# 290| 'took'          'took'
# 291| 'command'       'command'
# 292| 'of'
# 293| 'the'
# 294| 'ship'          'ship'
# 295| 'on'
# 296| 'stardate'      'stardate'
# 297| '41148'         '41148'
# 298| 'at'
# 299| 'the'
# 300| 'order'         'order'
# 301| 'of'
# 302| 'Rear'          'Rear'
# 303| 'Admiral'       'Admiral'
# 304| 'Norah'         'Norah'
# 305| 'Satie'         'Satie'
# 306| 'Legacy'        'Legacy'
# 307| 'Commander'     'Commander'
# 308| 'Riker'         'Riker'
# 309| 'was'
# 310| 'upset'         'upset'
# 311| 'over'
# 312| 'the'
# 313| 'loss'          'loss'
# 314| 'of'
# 315| 'the'
# 316| 'Enterprise'    'Enterprise'
# 317| 'Having'
# 318| 'hoped'         'hoped'
# 319| 'he'
# 320| 'would'         'would'
# 321| 'one'           'one'
# 322| 'day'           'day'
# 323| 'command'       'command'
# 324| 'the'
# 325| 'ship'          'ship'
# 326| ','             ','
# 327| 'he'
# 328| 'was'
# 329| 'disappointed'  'disappointed'
# 330| 'that'
# 331| 'he'
# 332| 'never'         'never'
# 333| 'got'           'got'
# 334| 'that'
# 335| 'opportunity'   'opportunity'
# 336| 'However'       'However'
# 337| ','             ','
# 338| 'Picard'        'Picard'
# 339| 'expressed'     'expressed'
# 340| 'doubt'         'doubt'
# 341| 'that'
# 342| 'the'
# 343| 'Enterprise-D'  'Enterprise-D'
# 344| 'would'         'would'
# 345| 'be'
# 346| 'the'
# 347| 'last'          'last'
# 348| 'vessel'        'vessel'
# 349| 'to'
# 350| 'carry'         'carry'
# 351| 'the'
# 352| 'name'          'name'
# 353| 'The'
# 354| 'Enterprise'    'Enterprise'
# 355| 'was'
# 356| 'so'
# 357| 'dear'          'dear'
# 358| 'to'
# 359| 'Worf'          'Worf'
# 360| 'that'
# 361| ','             ','
# 362| 'shortly'       'shortly'
# 363| 'after'
# 364| 'being'
# 365| 'reassigned'    'reassigned'
# 366| 'to'
# 367| 'Deep'          'Deep'
# 368| 'Space'         'Space'
# 369| '9'             '9'
# 370| 'in'
# 371| '2372'          '2372'
# 372| ','             ','
# 373| 'he'
# 374| 'briefly'       'briefly'
# 375| 'considered'    'considered'
# 376| 'resigning'     'resigning'
# 377| 'from'
# 378| 'Starfleet'     'Starfleet'
# 379| 'Station'       'Station'
# 380| 'commander'     'commander'
# 381| 'Captain'       'Captain'
# 382| 'Benjamin'      'Benjamin'
# 383| 'Sisko'         'Sisko'
# 384| 'expressed'     'expressed'
# 385| 'regret'        'regret'
# 386| 'on'
# 387| 'the'
# 388| 'loss'          'loss'
# 389| 'of'
# 390| 'the'
# 391| 'Enterprise'    'Enterprise'
# 392| 'and'
# 393| 'offered'       'offered'
# 394| 'his'
# 395| 'condolences'   'condolences'
# 396| 'over'
# 397| 'the'
# 398| 'destruction'   'destruction'
# 399| 'of'
# 400| 'the'
# 401| 'ship'          'ship'
# 402| 'to'
# 403| 'Worf'          'Worf'
# 404| ','             ','
# 405| 'saying'        'saying'
# 406| 'the'
# 407| 'Enterprise'    'Enterprise'
# 408| 'was'
# 409| 'a'
# 410| 'good'          'good'
# 411| 'ship'          'ship'
# 412| 'Captain'       'Captain'
# 413| 'Picard'        'Picard'
# 414| "'s"            "'s"
# 415| 'belief'        'belief'
# 416| 'that'
# 417| 'the'
# 418| 'Enterprise-D'  'Enterprise-D'
# 419| 'would'         'would'
# 420| 'not'
# 421| 'be'
# 422| 'the'
# 423| 'final'         'final'
# 424| 'ship'          'ship'
# 425| 'to'
# 426| 'bear'          'bear'
# 427| 'the'
# 428| 'name'          'name'
# 429| 'was'
# 430| 'borne'         'borne'
# 431| 'out'
# 432| 'with'
# 433| 'the'
# 434| 'christening'   'christening'
# 435| 'of'
# 436| 'the'
# 437| 'Class'         'Class'
# 438| 'Sovereign'     'Sovereign'
# 439| 'USS'           'USS'
# 440| 'Enterprise'    'Enterprise'
# 441| 'NCC-1701-E'    'NCC-1701-E'
# 442| ','             ','
# 443| 'later'         'later'
# 444| 'the'
# 445| 'same'
# 446| 'year'          'year'
# 447| 'In'
# 448| 'that'
# 449| 'instance'      'instance'
# 450| ','             ','
# 451| 'the'
# 452| 'legacy'        'legacy'
# 453| 'of'
# 454| 'the'
# 455| 'Enterprise'    'Enterprise'
# 456| 'continued'     'continued'
# 457| 'with'
# 458| 'Picard'        'Picard'
# 459| 'reprising'     'reprising'
# 460| 'his'
# 461| 'role'          'role'
# 462| 'as'
# 463| 'CO'            'CO'
# 464| 'and'
# 465| 'selecting'     'selecting'
# 466| 'most'
# 467| 'of'
# 468| 'the'
# 469| 'former'        'former'
# 470| 'crew'          'crew'
# 471| 'from'
# 472| 'the'
# 473| 'Enterprise-D'  'Enterprise-D'
# 474| ','             ','
# 475| 'with'
# 476| 'the'
# 477| 'notable'       'notable'
# 478| 'exception'     'exception'
# 479| 'of'
# 480| 'Worf'          'Worf'
# 481| 'due'           'due'
# 482| 'to'
# 483| 'his'
# 484| 'most'
# 485| 'recent'        'recent'
# 486| 'assignment'    'assignment'
# 487| 'to'
# 488| 'DS9'           'DS9'
# 489| '('             '('
# 490| 'though'        'though'
# 491| 'he'
# 492| 'temporarily'   'temporarily'
# 493| 'joined'        'joined'
# 494| 'the'
# 495| 'Enterprise-E'  'Enterprise-E'
# 496| 'crew'          'crew'
# 497| 'on'
# 498| 'several'       'several'
# 499| 'of'
# 500| 'their'
# 501| 'more'
# 502| 'notable'       'notable'
# 503| 'missions'      'missions'
# 504| ')'             ')'

# %%
plot_words(tokens_no_stop)

# %% [markdown]
# ### Check Part of Speech

# %%
# define PoS
pos_list = {
    'CC':   'coordinating conjunction',
    'CD':   'cardinal digit',
    'DT':   'determiner',
    'EX':   'existential there (like: "there is" ... think of it like "there exists")',
    'FW':   'foreign word',
    'IN':   'preposition/subordinating conjunction',
    'JJ':   'adjective "big"',
    'JJR':  'adjective, comparative "bigger"',
    'JJS':  'adjective, superlative "biggest"',
    'LS':   'list marker 1)',
    'MD':   'modal could, will',
    'NN':   'noun, singular "desk"',
    'NNS':  'noun plural "desks"',
    'NNP':  'proper noun, singular "Harrison"',
    'NNPS': 'proper noun, plural "Americans"',
    'PDT':  'predeterminer "all the kids"',
    'POS':  'possessive ending parent"s',
    'PRP':  'personal pronoun I, he, she',
    'PRP$': 'possessive pronoun my, his, hers',
    'RB':   'adverb very, silently,',
    'RBR':  'adverb, comparative better',
    'RBS':  'adverb, superlative best',
    'RP':   'particle give up',
    'TO':   'to go "to" the store.',
    'UH':   'interjection errrrrrrrm',
    'VB':   'verb, base form take',
    'VBD':  'verb, past tense took',
    'VBG':  'verb, gerund/present participle taking',
    'VBN':  'verb, past participle taken',
    'VBP':  'verb, sing. present, non-3d take',
    'VBZ':  'verb, 3rd person sing. present takes',
    'WDT':  'wh-determiner which',
    'WP':   'wh-pronoun who, what',
    'WP$':  'possessive wh-pronoun whose',
    'WRB':  'wh-abverb where, when',
}

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/macbook/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
## nltk
tagged = nltk.pos_tag(tokens)

for i, t in enumerate(tagged[:25]):
    print('%2d|%-12r : %-4s %s' % (i+1, t[0], t[1], (pos_list[t[1]] if t[1] in pos_list else '-')))
# Out:
#  1|'USS'        : NNP  proper noun, singular "Harrison"
#  2|'Enterprise' : NNP  proper noun, singular "Harrison"
#  3|'('          : (    -
#  4|'NCC-1701-D' : NNP  proper noun, singular "Harrison"
#  5|')'          : )    -
#  6|'For'        : IN   preposition/subordinating conjunction
#  7|'five'       : CD   cardinal digit
#  8|'hundred'    : CD   cardinal digit
#  9|'years'      : NNS  noun plural "desks"
# 10|','          : ,    -
# 11|'every'      : DT   determiner
# 12|'ship'       : NN   noun, singular "desk"
# 13|'that'       : WDT  wh-determiner which
# 14|'has'        : VBZ  verb, 3rd person sing. present takes
# 15|'borne'      : VBN  verb, past participle taken
# 16|'the'        : DT   determiner
# 17|'name'       : NN   noun, singular "desk"
# 18|'of'         : IN   preposition/subordinating conjunction
# 19|'the'        : DT   determiner
# 20|'Enterprise' : NNP  proper noun, singular "Harrison"
# 21|'has'        : VBZ  verb, 3rd person sing. present takes
# 22|'become'     : VBN  verb, past participle taken
# 23|'a'          : DT   determiner
# 24|'legend'     : RBR  adverb, comparative better
# 25|'This'       : DT   determiner

# %% [markdown]
# ### Stemming

# %%
## nltk
ps = nltk.porter.PorterStemmer()
stemmed = ' '.join([ps.stem(word) for word in text.split()])

# %%
stemmed
# Out:
# "uss enterpris (ncc-1701-d) for five hundr years, everi ship that ha born the name of the enterpris ha becom a legend thi one is no differ the uss enterpris (ncc-1701-d) wa a 24th centuri unit feder of planet galaxi class starship oper by starfleet, and the fifth feder ship to bear the name enterpris dure her career, the enterpris serv as the feder flagship the enterpris wa destroy dure the battl of veridian iii in 2371 histori construct and launch the enterpris wa built at utopia planitia fleet yard orbit mar in the solar system the construct wa a massiv undertaking, involv thousand of peopl across disciplin construct wa supervis by command orfil quintero dr leah brahm wa respons for much of the enterprise' warp propuls system design some of the enterprise' compon were deriv from technolog origin develop on the uss pegasu one of the ship' nacel tube wa the site of a multipl murder-suicid while she wa still under construct at utopia planitia a member of the construct team, walter pierce, becam jealou of a former lover' new relationship he kill the two officers, marla finn and william hodges, then dispos of their bodi in the plasma stream pierc commit suicid in the same manner, leav a telepath imprint in a bulkhead that wa not discov until 2370 on stardat 407595, in the year 2363, the enterpris wa launch from mar on stardat 410255, the enterpris wa commiss these stardat weren't mention in dialog; they were from the enterpris dedic plaqu final system complet and shakedown wa conduct at earth station mckinley captain jean-luc picard took command of the ship on stardat 41148 at the order of rear admir norah sati legaci command riker wa upset over the loss of the enterpris have hope he would one day command the ship, he wa disappoint that he never got that opportun however, picard express doubt that the enterprise-d would be the last vessel to carri the name the enterpris wa so dear to worf that, shortli after be reassign to deep space 9 in 2372, he briefli consid resign from starfleet station command captain benjamin sisko express regret on the loss of the enterpris and offer hi condol over the destruct of the ship to worf, say the enterpris wa a good ship captain picard' belief that the enterprise-d would not be the final ship to bear the name wa born out with the christen of the class sovereign uss enterpris ncc-1701-e, later the same year in that instance, the legaci of the enterpris continu with picard repris hi role as co and select most of the former crew from the enterprise-d, with the notabl except of worf due to hi most recent assign to ds9 (though he temporarili join the enterprise- crew on sever of their more notabl missions)"

# %% [markdown]
# ### Lemmatisation

# %%
## nltk
wl = nltk.stem.WordNetLemmatizer()
lemma = ' '.join([wl.lemmatize(word) for word in text.split()])

# %%
## nltk
dot = stemmed.find('.') + 1
sl = stemmed[:dot].split()
dot = lemma.find('.') + 1
ll = lemma[:dot].split()

print('i | Stem           Lemma')
print('--| -------------- ------------')
for i, p in enumerate(zip(sl, ll)):
    print('%2d| %-12r   %-12r' % (i+1, p[0], p[1]))
# Out:
# i | Stem           Lemma
# --| -------------- ------------

# %%
plot_words(stemmed.split())

# %%
plot_words(lemma.split())

# %% [markdown]
# ### Entity recognition

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/macbook/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/macbook/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
## nltk
entities = nltk.chunk.ne_chunk(tagged)

for e in entities:
    s = re.sub(r'[\(\)]', '', str(e))
    if s.find('/NNP') > 0:
        t = s.split()[0]
        n = ' '.join([re.sub(r'/NNP', '', x) for x in s.split()[1:]])
        print('%-12s: %s' % (t, n))
# Out:
# ORGANIZATION: USS Enterprise
# ORGANIZATION: Enterprise
# ORGANIZATION: USS Enterprise
# PERSON      : United Federation
# ORGANIZATION: Planets Galaxy
# PERSON      : Starfleet
# ORGANIZATION: Enterprise
# ORGANIZATION: Federation
# ORGANIZATION: Enterprise
# ORGANIZATION: Battle
# GPE         : Veridian
# ORGANIZATION: Enterprise
# ORGANIZATION: Utopia Planitia Fleet
# PERSON      : Mars
# ORGANIZATION: Solar
# ORGANIZATION: Commander Orfil Quinteros
# PERSON      : Brahms
# ORGANIZATION: Enterprise
# ORGANIZATION: Enterprise
# ORGANIZATION: USS
# ORGANIZATION: Utopia
# PERSON      : Walter Pierce
# PERSON      : Marla Finn
# PERSON      : William Hodges
# PERSON      : Pierce
# ORGANIZATION: Enterprise
# PERSON      : Mars
# ORGANIZATION: Enterprise
# ORGANIZATION: Enterprise
# FACILITY    : Earth Station
# ORGANIZATION: McKinley Captain
# PERSON      : Picard
# ORGANIZATION: Rear Admiral Norah Satie Legacy
# PERSON      : Riker
# ORGANIZATION: Enterprise
# PERSON      : Picard
# ORGANIZATION: Enterprise
# PERSON      : Deep Space
# PERSON      : Starfleet Station
# PERSON      : Captain Benjamin Sisko
# ORGANIZATION: Enterprise
# GPE         : Worf
# ORGANIZATION: Enterprise
# PERSON      : Captain Picard
# ORGANIZATION: Class Sovereign
# ORGANIZATION: Enterprise
# PERSON      : Picard
# ORGANIZATION: CO
# GPE         : Worf
# ORGANIZATION: DS9

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
