# %%
import pandas as pd
import datetime
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/macbook/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
textdf = pd.read_csv('abcnews-date-text.csv')
text
# Out:
#         publish_date                                      headline_text  \
# 0         2003-02-19  aba decides against community broadcasting lic...
# 1         2003-02-19     act fire witnesses must be aware of defamation
# 2         2003-02-19     a g calls for infrastructure protection summit
# 3         2003-02-19           air nz staff in aust strike for pay rise
# 4         2003-02-19      air nz strike to affect australian travellers
# ...              ...                                                ...
# 1244179   2021-12-31  two aged care residents die as state records 2...
# 1244180   2021-12-31  victoria records 5;919 new cases and seven deaths
# 1244181   2021-12-31    wa delays adopting new close contact definition
# 1244182   2021-12-31  western ringtail possums found badly dehydrate...
# 1244183   2021-12-31  what makes you a close covid contact here are ...
#
#          compound_score
# 0                0.0000
# 1               -0.3400
# 2                0.0000
# 3               -0.2263
# 4               -0.1280
# ...                 ...
# 1244179         -0.1779
# 1244180          0.0000
# 1244181          0.0000
# 1244182         -0.4767
# 1244183          0.0000
#
# [1244184 rows x 3 columns]

# %%
textdf.dtypes
# Out:
# publish_date      int64
# headline_text    object
# dtype: object

# %%
textdf.shape
# Out:
# (1244184, 2)

# %%
textdf.columns = ['date', 'headline']

# %%
textdf
# Out:
#              date                                           headline
# 0        20030219  aba decides against community broadcasting lic...
# 1        20030219     act fire witnesses must be aware of defamation
# 2        20030219     a g calls for infrastructure protection summit
# 3        20030219           air nz staff in aust strike for pay rise
# 4        20030219      air nz strike to affect australian travellers
# ...           ...                                                ...
# 1244179  20211231  two aged care residents die as state records 2...
# 1244180  20211231  victoria records 5;919 new cases and seven deaths
# 1244181  20211231    wa delays adopting new close contact definition
# 1244182  20211231  western ringtail possums found badly dehydrate...
# 1244183  20211231  what makes you a close covid contact here are ...
#
# [1244184 rows x 2 columns]

# %%
textdf['date'] = pd.to_datetime(textdf['date'], format='%Y%m%d')

# %%
textdf.head()
# Out:
#         date                                           headline
# 0 2003-02-19  aba decides against community broadcasting lic...
# 1 2003-02-19     act fire witnesses must be aware of defamation
# 2 2003-02-19     a g calls for infrastructure protection summit
# 3 2003-02-19           air nz staff in aust strike for pay rise
# 4 2003-02-19      air nz strike to affect australian travellers

# %%
vader = SentimentIntensityAnalyzer()
f = lambda headline: vader.polarity_scores(headline)['compound']

# %%
textdf['compound_score'] = textdf['headline'].apply(f)

# %%
textdf.head()
# Out:
#         date                                           headline  \
# 0 2003-02-19  aba decides against community broadcasting lic...
# 1 2003-02-19     act fire witnesses must be aware of defamation
# 2 2003-02-19     a g calls for infrastructure protection summit
# 3 2003-02-19           air nz staff in aust strike for pay rise
# 4 2003-02-19      air nz strike to affect australian travellers
#
#    compound_score
# 0          0.0000
# 1         -0.3400
# 2          0.0000
# 3         -0.2263
# 4         -0.1280

# %%
mean_score = textdf.groupby(['date']).mean()

# %%
mean_score.tail()
# Out:
#             compound_score
# date
# 2021-12-27       -0.114184
# 2021-12-28       -0.052474
# 2021-12-29        0.006050
# 2021-12-30        0.016529
# 2021-12-31        0.008130

# %%
mean_score['compound_score'].plot(style='-', figsize=(15, 5))
plt.show()

# %%
cba = pd.read_excel('CBA.xls')
cba
# Out:
#            Date        Open        High         Low       Close  Adj Close  \
# 0    2003-02-19   24.527111   24.596733   24.009914   24.178999   8.582987
# 4785  1548336.0  0.480004
# 4786  1015385.0  0.269997
# 4787  1198104.0 -1.269997
#
# [4788 rows x 8 columns]

# %%
cba['movement'].plot(style='-', figsize=(15, 5))
plt.show()

# %%
merge = pd.merge_asof(mean_score, cba, on='date')

# %%
merge
# Out:
#            date  compound_score        open        high         low  \
# 0    2003-02-19       -0.107614   24.527111   24.596733   24.009914
# 1    2003-02-20       -0.110760   24.119322   24.258568   23.880613
# 2    2003-02-21       -0.104719   23.840830   24.547005   23.691639
# 3    2003-02-22       -0.052789   23.840830   24.547005   23.691639
# 4    2003-02-23       -0.099331   23.840830   24.547005   23.691639
# ...         ...             ...         ...         ...         ...
# 6877 2021-12-27       -0.114184  100.580002  101.139999  100.580002
# 6878 2021-12-28       -0.052474  100.580002  101.139999  100.580002
# 6879 2021-12-29        0.006050  101.419998  102.370003  101.370003
# 6880 2021-12-30        0.016529  102.000000  102.580002  101.709999
# 6881 2021-12-31        0.008130  102.269997  102.665001  101.000000
#
#            close  adj close     volume  movement
# 0      24.178999   8.582987  7242608.0 -0.348112
# 1      23.880613   8.477066  4411893.0 -0.238709
# 2      24.517164   8.703027  4636529.0  0.676334
# 3      24.517164   8.703027  4636529.0  0.676334
# 4      24.517164   8.703027  4636529.0  0.676334
# ...          ...        ...        ...       ...
# 6877  100.629997  96.813759   888168.0  0.049995
# 6878  100.629997  96.813759   888168.0  0.049995
# 6879  101.900002  98.035606  1548336.0  0.480004
# 6880  102.269997  98.391563  1015385.0  0.269997
# 6881  101.000000  97.169731  1198104.0 -1.269997
#
# [6882 rows x 9 columns]

# %%
newdf = merge.copy()

# %%
newdf.index = newdf.pop('date')

# %%
newdf
# Out:
#             compound_score        open        high         low       close  \
# date
# 2003-02-19       -0.107614   24.527111   24.596733   24.009914   24.178999
# 2003-02-20       -0.110760   24.119322   24.258568   23.880613   23.880613
# 2003-02-21       -0.104719   23.840830   24.547005   23.691639   24.517164
# 2003-02-22       -0.052789   23.840830   24.547005   23.691639   24.517164
# 2003-02-23       -0.099331   23.840830   24.547005   23.691639   24.517164
# ...                    ...         ...         ...         ...         ...
# 2021-12-27       -0.114184  100.580002  101.139999  100.580002  100.629997
# 2021-12-28       -0.052474  100.580002  101.139999  100.580002  100.629997
# 2021-12-29        0.006050  101.419998  102.370003  101.370003  101.900002
# 2021-12-30        0.016529  102.000000  102.580002  101.709999  102.269997
# 2021-12-31        0.008130  102.269997  102.665001  101.000000  101.000000
#
#             adj close     volume  movement
# date
# 2003-02-19   8.582987  7242608.0 -0.348112
# 2003-02-20   8.477066  4411893.0 -0.238709
# 2003-02-21   8.703027  4636529.0  0.676334
# 2003-02-22   8.703027  4636529.0  0.676334
# 2003-02-23   8.703027  4636529.0  0.676334
# ...               ...        ...       ...
# 2021-12-27  96.813759   888168.0  0.049995
# 2021-12-28  96.813759   888168.0  0.049995
# 2021-12-29  98.035606  1548336.0  0.480004
# 2021-12-30  98.391563  1015385.0  0.269997
# 2021-12-31  97.169731  1198104.0 -1.269997
#
# [6882 rows x 8 columns]

# %%
x = newdf.index
y1 = newdf['compound_score']
y2 = newdf['movement']

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
curve1 = ax1.plot(x, y1, label = 'Compound score', color='r')
curve2 = ax2.plot(x, y2, label = 'Stock movement', color='b')

plt.plot()
plt.show()
